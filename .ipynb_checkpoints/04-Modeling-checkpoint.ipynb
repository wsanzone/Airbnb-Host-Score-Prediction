# %% [markdown]
# ![Airbnb_Logo_Be%CC%81lo.svg.png](attachment:Airbnb_Logo_Be%CC%81lo.svg.png)

# %% [markdown]
# # Airbnb Host Score Prediction: Modeling, Evaluation and Conclusion

# %% [markdown]
# Notebook: 4 of 4

# %% [markdown]
# ## Recap
#
# This far in the project, we have done the following:
# - Cleaned the data
# - Explored the data using visuals such as maps and charts
# - Performed basic feature engineering
# - Encoded the data using a vareity of methods such as Tfidf Vectorization, Multi-Label Binarization, and One Hot Encoding
#
#
# --------
#
# ## Purpose
#
# The purpose of this notebook is to test out a few different model types, tune their hyperparameters, evaluate those models, and select a final model to proceed with

# %% [markdown]
# ## Please Note: You will need the specified environment to run this notebook successfully. Please download the respective `modeling_env.yml` file
#
# Instructions to set up an environment from a `.yml` file can be found here: https://conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html#creating-an-environment-from-an-environment-yml-file

# %% [markdown]
# Let's import the relevant libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Now we can read in our data, remember our train test split has already been completed in the Encoding notebook.

# %%
X_train = pd.read_csv('Modeling_Datasets/X_train_processed.csv')
X_val = pd.read_csv('Modeling_Datasets/X_val_processed.csv')
X_test = pd.read_csv('Modeling_Datasets/X_test_processed.csv')

# %%
y_train = pd.read_csv('Modeling_Datasets/y_train_binary.csv')
y_val = pd.read_csv('Modeling_Datasets/y_val_binary.csv')
y_test = pd.read_csv('Modeling_Datasets/y_test_binary.csv')

# %% [markdown]
# Let's check the shapes of each dataset:

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (17550, 463)
# (7522, 463)
# (10746, 463)

# %%
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (17550, 1)
# (7522, 1)
# (10746, 1)

# %% [markdown]
# Our target datasets are not in the correct format for a lot of the models that we will try. Let's convert them using the `np.ravel()` method from the `numpy` library.

# %%
y_train = np.ravel(y_train)
y_val = np.ravel(y_val)
y_test = np.ravel(y_test)

# %% [markdown]
# Let's double check to make sure that has worked.

# %%
print(f'New y_train shape: {y_train.shape}')
print(f'New y_val shape: {y_val.shape}')
print(f'New y_test shape: {y_test.shape}')
# Out:
# New y_train shape: (17550,)
# New y_val shape: (7522,)
# New y_test shape: (10746,)

# %% [markdown]
# Great, let's run our first model. We will start with a Decision Tree Classifier.

# %% [markdown]
# ## Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# The main hyperparameter of a decision tree model is the `max_depth`. Here we will be looping over various depth values and plotting the accuracy scores of each.

# %%
train_accs = []
val_accs = []

for depth in range(1, 15): # Iterating over depths from 1 to 15
    
    #instantiate
    dt_model = DecisionTreeClassifier(max_depth = depth) # Instantiate the model
    
    # fit
    dt_model.fit(X_train, y_train)
    
    # score on train and validation sets
    train_score = dt_model.score(X_train, y_train)
    val_score = dt_model.score(X_val, y_val)
    
    #Append to lists
    train_accs.append(train_score)
    val_accs.append(val_score)

# %% [markdown]
# Now we can plot the results, and decide on a `max_depth` for our testing set:

# %%
# Plotting the results
plt.figure()
plt.plot(range(1, 15), train_accs, label='train', marker='o')
plt.plot(range(1, 15), val_accs, label='validation', marker='o')
plt.xlabel('Max Depth')
plt.ylabel('Accuracy Score')
plt.legend()
plt.show()

# %% [markdown]
# It looks like our best validation score that is less than the training score is around a `max_depth` of 6. We will use that parameter for our tuned model:

# %%
final_dt_model = DecisionTreeClassifier(max_depth = 6) # Instantiate the model

# Fit the model
final_dt_model.fit(X_train, y_train)

# Score the model
training_score = final_dt_model.score(X_train, y_train)
testing_score = final_dt_model.score(X_test, y_test)

# Print the scores
print(f'Training Score: {round(training_score, 3)}')
print(f'Testing Score: {round(testing_score, 3)}')
# Out:
# Training Score: 0.888
# Testing Score: 0.876

# %% [markdown]
# That did pretty well! The model was able to predict a good versus a bad review with almost 88% accuracy on the testing set, and does not seem to be overfitting. Let's invesigate these results a bit further with a confusion matrix, precision score, recall score and F1 score:

# %%
from sklearn.metrics import plot_confusion_matrix, confusion_matrix, precision_score, recall_score, f1_score

# %% [markdown]
# To calculate precision, recall and the F1 score, we will need to generate predictions from our model:

# %%
y_pred = final_dt_model.predict(X_test)

# %% [markdown]
# We can calculate precision score by simply calling the method. It is important to note the order of arguments: test set first, followed by predictions. This applies to precision, recall and the F1 Score

# %%
precision_score(y_test, y_pred)
# Out:
# 0.8880546075085324

# %%
recall_score(y_test, y_pred)
# Out:
# 0.9266381766381766

# %%
f1_score(y_test, y_pred)
# Out:
# 0.9069362147089578

# %% [markdown]
# Let's create a DataFrame to store all of our model evaluation metrics:

# %%
data = [['DT_w_predictors', 'First DT Model', precision_score(y_test, y_pred),
       recall_score(y_test, y_pred), f1_score(y_test, y_pred)]]
model_comparison_df = pd.DataFrame(data, columns=['Model Instance', 'description', 'precision', 'recall', 'F1'])

# %%
model_comparison_df
# Out:
#     Model Instance     description  precision    recall        F1
# 0  DT_w_predictors  First DT Model   0.888055  0.926638  0.906936

# %% [markdown]
# Now we have a readable format in which we can compare our models. Let's also look at the confusion matrix for this model:

# %%
plot_confusion_matrix(final_dt_model, X_test, y_test, cmap='Reds');

# %% [markdown]
# That did pretty good! Some important insights are below:
# - The model had 515 false negatives
# - The model had 819 false positives
# - This model was generally able to predict whether a review was good or bad

# %% [markdown]
# Let's see how this model was making it's decisions. We can do that by using the `plot_tree` method from sklearn.

# %%
from sklearn.tree import plot_tree

# %%
fig, ax = plt.subplots(figsize=(25, 15))

plot_tree(final_dt_model,
         feature_names=X_test.columns,
         rounded=True,
         impurity=False,
         filled=True,
         ax=ax,
         fontsize=9);

# %% [markdown]
# From the above tree, the model is classifying a host's review score based on their other review scores! This is not good if we are trying to predict a new host's review score. We will remove these multicollinear features below:

# %%
cols_to_remove = ['review_scores_accuracy', 'review_scores_cleanliness',
 'review_scores_checkin', 'review_scores_communication',
 'review_scores_location', 'review_scores_value']

dataframes = [X_train, X_val, X_test]

for df in dataframes: # Looping over our values
    df.drop(columns=cols_to_remove, inplace=True)
    
# Checking to make sure that it has worked
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (17550, 457)
# (7522, 457)
# (10746, 457)

# %% [markdown]
# Let's try the same Decision Tree Model again:

# %%
train_accs = []
val_accs = []

for depth in range(1, 15):
    
    #instantiate
    dt_model1 = DecisionTreeClassifier(max_depth = depth)
    
    # fit
    dt_model1.fit(X_train, y_train)
    
    # score on train and validation sets
    train_score = dt_model1.score(X_train, y_train)
    val_score = dt_model1.score(X_val, y_val)
    
    #Append to lists
    train_accs.append(train_score)
    val_accs.append(val_score)

# %%
# Plotting the results
plt.figure()
plt.plot(range(1, 15), train_accs, label='train', marker='o')
plt.plot(range(1, 15), val_accs, label='validation', marker='o')
plt.xlabel('Max Depth')
plt.ylabel('Accuracy Score')
plt.legend()
plt.show()

# %% [markdown]
# Those scores are much different! It looks like our model begins overfitting at a `max_depth` of around 6. Our best validation score seems to be at a `max_depth` of around 3. We will run the model on the testing set using that value.

# %%
final_dt_model = DecisionTreeClassifier(max_depth = 3) # Instantiate the model

# Fit the model
final_dt_model.fit(X_train, y_train)

# Score the model
training_score = final_dt_model.score(X_train, y_train)
testing_score = final_dt_model.score(X_test, y_test)

# Print the results
print(f'Training Score: {round(training_score, 5)}')
print(f'Testing Score: {round(testing_score, 5)}')
# Out:
# Training Score: 0.69783
# Testing Score: 0.69337

# %% [markdown]
# That accuracy score does not seem too bad, but with imbalanced data we have to remember that if we were to predict only the positive class, we would have an accuracy of ~65%

# %%
pd.Series(y_test).value_counts()[1] / y_test.shape[0]
# Out:
# 0.6532663316582915

# %% [markdown]
# Let's generate our predictions so we can add this model to our dataframe.

# %%
y_pred = final_dt_model.predict(X_test)

# %%
data = ['DT_w_tuning', 'Second DT Model', precision_score(y_test, y_pred),
       recall_score(y_test, y_pred), f1_score(y_test, y_pred)]
data
# Out:
# ['DT_w_tuning',
#  'Second DT Model',
#  0.7108570134722065,
#  0.8944444444444445,
#  0.7921529048129692]

# %%
model_comparison_df.loc[len(model_comparison_df)] = data
model_comparison_df
# Out:
#     Model Instance      description  precision    recall        F1
# 0  DT_w_predictors   First DT Model   0.888055  0.926638  0.906936
# 1      DT_w_tuning  Second DT Model   0.710857  0.894444  0.792153

# %% [markdown]
# Below is a function which does the steps of the above cells:

# %%
def add_results(model, df, X_test, y_test, model_name, model_desc):
    y_pred = model.predict(X_test)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    data = [model_name, model_desc, precision, recall, f1]
    df.loc[len(df)] = data
    return df

# %% [markdown]
# Let's see how this decision tree is making it's decisions:

# %%
fig, ax = plt.subplots(figsize=(25, 15))

plot_tree(final_dt_model,
         feature_names=X_test.columns,
         rounded=True,
         impurity=False,
         filled=True,
         ax=ax,
         fontsize=12);

# %% [markdown]
# That is interesting to see how the model is making decisions. The most important variable was `host_is_superhost` followed by `calculated_host_listings_count` and `number_of_reviews_ltm`. Let's plot the confusion matrix.

# %%
plot_confusion_matrix(final_dt_model, X_test, y_test, cmap='Reds');

# %% [markdown]
# Compared to our first decision tree model, this model had a much higher false positive rate, with 2,554 false positives.
#
# -------
#
# That will conclude our testing of the Decision Tree model, let's now try a random forest model.

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
ss.fit(X_train)
X_train_ss = ss.transform(X_train)
X_val_ss = ss.transform(X_val)
X_test_ss = ss.transform(X_test)

# %% [markdown]
# The random forest model has two primary hyperparameters that we can tune:
# - `n_estimators`
# - `max_depth`
#
# We will first tune the number of estimators and then tune the max depth

# %%
n_estimators_range = range(1, 51)
results = pd.DataFrame()
for estimator in n_estimators_range:
    
    # Instantiate the model
    rf = RandomForestClassifier(n_estimators = estimator, random_state=10)
    
    #Fit the model
    rf.fit(X_train_ss, y_train)
    
    # Score the model and append to a list
    train_score = rf.score(X_train_ss, y_train)
    val_score = rf.score(X_val_ss, y_val)
    
    results = results.append(
    {'n_estimators': estimator, 'train': train_score, 'validation': val_score}, ignore_index=True)
    
    print(estimator, end='\r')
# Out:
# 50

# %% [markdown]
# Now we can plot these results and select `n_estimators`:

# %%
plt.figure(figsize=(10, 7))
results.plot(x="n_estimators", y=["train", "validation"], kind="line", ax=plt.gca())
plt.legend()
plt.title("Random Forest CV scores with different number of estimators")
plt.show()

# %% [markdown]
# Definitely overfitting here, let's try tuning `max_depth` with the best value from the above graph:

# %%
# Getting the best validation score
max_x = results.loc[results['validation'].idxmax()]
max_x
# Out:
# n_estimators    49.000000
# train            1.000000
# validation       0.679474
# Name: 48, dtype: float64

# %% [markdown]
# Let's further tune this model with a `n_estimators` of 49:

# %%
max_depths = range(1, 31)
results = pd.DataFrame()
for depth in max_depths:
    # Instantiate the model
    rf = RandomForestClassifier(n_estimators = 49, max_depth=depth, random_state=10)
    
    # Fit the model
    rf.fit(X_train_ss, y_train)
    
    # Score the model and append to lists
    train_score = rf.score(X_train_ss, y_train)
    val_score = rf.score(X_val_ss, y_val)
    
    results = results.append(
    {'max_depth': depth, 'train': train_score, 'validation': val_score}, ignore_index=True)
    
    print(depth, end='\r')
# Out:
# 30

# %% [markdown]
# Now to plot these results:

# %%
plt.figure(figsize=(10, 7))
results.plot(x="max_depth", y=["train", "validation"], kind="line", ax=plt.gca())
plt.legend()
plt.title("Random Forest CV scores with different maximum depths")
plt.show()

# %%
# Getting the best validation score
max_depth = results.loc[results['validation'].idxmax()]
max_depth
# Out:
# max_depth     14.000000
# train          0.856581
# validation     0.701941
# Name: 13, dtype: float64

# %% [markdown]
# Ok, for our final model we will use `n_estimators` = 49 and `max_depth` = 14.

# %%
# Instantiate the model
final_rf = RandomForestClassifier(max_depth=14, n_estimators=49, random_state=10)

# Fit the model
final_rf.fit(X_train_ss, y_train)

# Score the model
train_score = final_rf.score(X_train_ss, y_train)
test_score = final_rf.score(X_test_ss, y_test)

# %% [markdown]
# And to print the results:

# %%
print(f'Training Score: {train_score}')
print(f'Testing Score: {test_score}')
# Out:
# Training Score: 0.8565811965811966
# Testing Score: 0.6851851851851852

# %% [markdown]
# That model also appears to be overfitting with the large delta between training and testing accuracy. Let's add this result to our DataFrame and plot the confusion matrix:

# %%
add_results(final_rf, model_comparison_df, X_test_ss, y_test, 'Tuned Random Forest', 'first tuned RF')
# Out:
#         Model Instance      description  precision    recall        F1
# 0      DT_w_predictors   First DT Model   0.888055  0.926638  0.906936
# 1          DT_w_tuning  Second DT Model   0.710857  0.894444  0.792153
# 2  Tuned Random Forest   first tuned RF   0.708951  0.878917  0.784837

# %%
plot_confusion_matrix(final_rf, X_test_ss, y_test, cmap='Reds');

# %% [markdown]
# Similar to our last decision tree model, the random forest model also has a high false positive rate. That will conclude our foray into random forest models. We will not be trying a Gradient Boosting model:

# %% [markdown]
# ## Gradient Boosting Model

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# Let's try a gradient boosting model without modifying any of it's hyperparameters:

# %%
# Instantiate the model
grad_boost = GradientBoostingClassifier(random_state=10)

#Fit the model
grad_boost.fit(X_train_ss, y_train)

# Score the model
train_score = grad_boost.score(X_train_ss, y_train)
val_score = grad_boost.score(X_val_ss, y_val)

# %% [markdown]
# And now to print the results:

# %%
print(f'Training Score on Basic Gradient Boost Model: {train_score}')
print(f'Validation Score on Basic Gradient Boost Model: {val_score}')
# Out:
# Training Score on Basic Gradient Boost Model: 0.7388603988603989
# Validation Score on Basic Gradient Boost Model: 0.6979526721616591

# %% [markdown]
# Not bad! Right off the bat this model is doing pretty well. Let's look at our evaluation metrics:

# %%
grad_boost.score(X_test_ss, y_test)
# Out:
# 0.6942117997394379

# %%
add_results(grad_boost, model_comparison_df, X_test_ss, y_test, 'Gradient Boosting', 'out of the box')
# Out:
#         Model Instance      description  precision    recall        F1
# 0      DT_w_predictors   First DT Model   0.888055  0.926638  0.906936
# 1          DT_w_tuning  Second DT Model   0.710857  0.894444  0.792153
# 2  Tuned Random Forest   first tuned RF   0.708951  0.878917  0.784837
# 3    Gradient Boosting   out of the box   0.777580  0.745014  0.760949

# %%
plot_confusion_matrix(grad_boost, X_test_ss, y_test, cmap='Reds');

# %% [markdown]
# Not a bad confusion matrix here, roughly an equal amount of false positives and false negatives. That model did take awhile to run though. There is a similar model type called the XGBoost model that performs roughly the same and is much quicker than the gradient boost model.

# %% [markdown]
# ## XGBoost Model

# %%
from xgboost import XGBClassifier

# %% [markdown]
# Let's also try this model out of the box:

# %%
xgb_model = XGBClassifier(random_state=10)

xgb_model.fit(X_train_ss, y_train)
xgb_model.score(X_train_ss, y_train)
# Out:
# 0.9162393162393162

# %%
xgb_model.score(X_val_ss, y_val)
# Out:
# 0.6847912789151821

# %%
xgb_model.score(X_test_ss, y_test)
# Out:
# 0.6827656802531175

# %% [markdown]
# Not bad! This model performed roughly the same as our Gradient Boosting model, but does seem to be largely overfitting. Let's look at our evaluation metrics:

# %%
add_results(xgb_model, model_comparison_df, X_test_ss, y_test, 'First XGBoost', 'out of the box')
# Out:
#         Model Instance      description  precision    recall        F1
# 0      DT_w_predictors   First DT Model   0.888055  0.926638  0.906936
# 1          DT_w_tuning  Second DT Model   0.710857  0.894444  0.792153
# 2  Tuned Random Forest   first tuned RF   0.708951  0.878917  0.784837
# 3    Gradient Boosting   out of the box   0.777580  0.745014  0.760949
# 4        First XGBoost   out of the box   0.751989  0.767521  0.759676

# %%
plot_confusion_matrix(xgb_model, X_test_ss, y_test, cmap='Reds');

# %% [markdown]
# This is a similar confusion matrix to our Gradient Boosting model. Let's tune the hyperparameters of this model and see if we can improve any of it's scores. We can do this by doing a grid search:

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# We will try out a few different parameters:
# - `n_estimators` ranging from 1 to 500 in increments of 100
# - `max_depth` ranging from 1 to 5

# %% [markdown]
# **Warning: The below cell will take a while to run**

# %%
my_xgb = XGBClassifier(n_jobs=-1)

param_grid = {'n_estimators': np.arange(1, 501, 100), 'max_depth': np.arange(1, 5)}

grid_xgb = GridSearchCV(my_xgb, param_grid=param_grid, verbose=3, n_jobs=-1, cv=5)

grid_xgb.fit(X_train_ss, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      gamma=None, gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=-1,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, reg_alpha=None,
#                                      reg_lambda=None, ...),
#              n_jobs=-1,
#              param_grid={'max_depth': array([1, 2, 3, 4]),
#                          'n_estimators': array([  1, 101, 201, 301, 401])},
#              verbose=3)

# %% [markdown]
# We can return the best estimators for this grid search using the `best_params` method:

# %%
grid_xgb.best_params_
# Out:
# {'max_depth': 1, 'n_estimators': 301}

# %% [markdown]
# To further refine our search:

# %%
my_xgb = XGBClassifier(n_jobs=-1)

param_grid = {'n_estimators': np.arange(295, 306), 'booster': ['gbtree', 'gblinear', 'dart']}

grid_xgb = GridSearchCV(my_xgb, param_grid=param_grid, verbose=3, n_jobs=-1, cv=5)

grid_xgb.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 33 candidates, totalling 165 fits
# [CV 5/5] END ..booster=gbtree, n_estimators=295;, score=0.712 total time= 1.9min
# [CV 2/5] END ..booster=gbtree, n_estimators=297;, score=0.708 total time= 1.9min
# [CV 4/5] END ..booster=gbtree, n_estimators=298;, score=0.699 total time= 1.9min
# [CV 2/5] END ..booster=gbtree, n_estimators=300;, score=0.708 total time= 1.9min
# [CV 5/5] END ..booster=gbtree, n_estimators=301;, score=0.711 total time= 1.9min
# [CV 3/5] END ..booster=gbtree, n_estimators=303;, score=0.705 total time= 1.9min
# [CV 1/5] END ..booster=gbtree, n_estimators=305;, score=0.707 total time= 1.9min
# [CV 5/5] END booster=gblinear, n_estimators=297;, score=0.684 total time=  10.0s
# [CV 3/5] END booster=gblinear, n_estimators=299;, score=0.690 total time=  10.0s
# [CV 1/5] END booster=gblinear, n_estimators=301;, score=0.694 total time=  10.3s
# [CV 4/5] END booster=gblinear, n_estimators=302;, score=0.689 total time=  10.1s
# [CV 2/5] END booster=gblinear, n_estimators=304;, score=0.686 total time=  10.0s
# [CV 5/5] END booster=gblinear, n_estimators=305;, score=0.684 total time=  10.2s
# [CV 3/5] END ....booster=dart, n_estimators=296;, score=0.707 total time=12.0min
# [CV 1/5] END ....booster=dart, n_estimators=298;, score=0.705 total time=11.9min
# [CV 4/5] END ....booster=dart, n_estimators=299;, score=0.699 total time=12.9min
# [CV 2/5] END ....booster=dart, n_estimators=301;, score=0.709 total time=12.6min
# [CV 5/5] END ....booster=dart, n_estimators=302;, score=0.711 total time=11.9min
# [CV 3/5] END ....booster=dart, n_estimators=304;, score=0.704 total time=11.9min
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      gamma=None, gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_ca...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=-1,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, reg_alpha=None,
#                                      reg_lambda=None, ...),
#              n_jobs=-1,
#              param_grid={'booster': ['gbtree', 'gblinear', 'dart'],
#                          'n_estimators': array([295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305])},
#              verbose=3)
# [CV 4/5] END ..booster=gbtree, n_estimators=295;, score=0.699 total time= 1.9min
# [CV 3/5] END ..booster=gbtree, n_estimators=297;, score=0.706 total time= 1.9min
# [CV 1/5] END ..booster=gbtree, n_estimators=299;, score=0.706 total time= 1.9min
# [CV 5/5] END ..booster=gbtree, n_estimators=300;, score=0.711 total time= 1.9min
# [CV 3/5] END ..booster=gbtree, n_estimators=302;, score=0.705 total time= 1.9min
# [CV 5/5] END ..booster=gbtree, n_estimators=303;, score=0.710 total time= 1.9min
# [CV 3/5] END ..booster=gbtree, n_estimators=305;, score=0.705 total time= 1.9min
# [CV 1/5] END booster=gblinear, n_estimators=298;, score=0.694 total time=   9.9s
# [CV 4/5] END booster=gblinear, n_estimators=299;, score=0.689 total time=  10.0s
# [CV 2/5] END booster=gblinear, n_estimators=301;, score=0.686 total time=  10.3s
# [CV 5/5] END booster=gblinear, n_estimators=302;, score=0.684 total time=  10.3s
# [CV 3/5] END booster=gblinear, n_estimators=304;, score=0.689 total time=  10.0s
# [CV 1/5] END ....booster=dart, n_estimators=295;, score=0.705 total time=12.0min
# [CV 4/5] END ....booster=dart, n_estimators=296;, score=0.699 total time=11.8min
# [CV 2/5] END ....booster=dart, n_estimators=298;, score=0.707 total time=12.8min
# [CV 5/5] END ....booster=dart, n_estimators=299;, score=0.711 total time=12.5min
# [CV 3/5] END ....booster=dart, n_estimators=301;, score=0.706 total time=11.9min
# [CV 1/5] END ....booster=dart, n_estimators=303;, score=0.705 total time=11.9min
# [CV 4/5] END ....booster=dart, n_estimators=304;, score=0.699 total time=11.0min
# [CV 2/5] END ..booster=gbtree, n_estimators=296;, score=0.708 total time= 1.9min
# [CV 5/5] END ..booster=gbtree, n_estimators=297;, score=0.711 total time= 1.9min
# [CV 5/5] END ..booster=gbtree, n_estimators=298;, score=0.711 total time= 1.9min
# [CV 3/5] END ..booster=gbtree, n_estimators=300;, score=0.706 total time= 1.9min
# [CV 1/5] END ..booster=gbtree, n_estimators=302;, score=0.705 total time= 1.9min
# [CV 4/5] END ..booster=gbtree, n_estimators=303;, score=0.700 total time= 1.9min
# [CV 2/5] END ..booster=gbtree, n_estimators=305;, score=0.707 total time= 1.9min
# [CV 2/5] END booster=gblinear, n_estimators=298;, score=0.686 total time=   9.9s
# [CV 1/5] END booster=gblinear, n_estimators=300;, score=0.694 total time=  10.0s
# [CV 4/5] END booster=gblinear, n_estimators=301;, score=0.689 total time=  10.3s
# [CV 1/5] END booster=gblinear, n_estimators=303;, score=0.694 total time=  10.2s
# [CV 4/5] END booster=gblinear, n_estimators=304;, score=0.689 total time=  10.1s
# [CV 2/5] END ....booster=dart, n_estimators=295;, score=0.708 total time=12.0min
# [CV 5/5] END ....booster=dart, n_estimators=296;, score=0.713 total time=11.8min
# [CV 3/5] END ....booster=dart, n_estimators=298;, score=0.706 total time=12.8min
# [CV 1/5] END ....booster=dart, n_estimators=300;, score=0.706 total time=12.5min
# [CV 4/5] END ....booster=dart, n_estimators=301;, score=0.698 total time=11.9min
# [CV 2/5] END ....booster=dart, n_estimators=303;, score=0.707 total time=11.8min
# [CV 5/5] END ....booster=dart, n_estimators=304;, score=0.712 total time=11.0min
# [CV 1/5] END ..booster=gbtree, n_estimators=295;, score=0.705 total time= 1.9min
# [CV 4/5] END ..booster=gbtree, n_estimators=297;, score=0.699 total time= 1.9min
# [CV 3/5] END ..booster=gbtree, n_estimators=299;, score=0.705 total time= 1.9min
# [CV 4/5] END ..booster=gbtree, n_estimators=300;, score=0.698 total time= 1.9min
# [CV 2/5] END ..booster=gbtree, n_estimators=302;, score=0.708 total time= 1.9min
# [CV 1/5] END ..booster=gbtree, n_estimators=304;, score=0.707 total time= 1.9min
# [CV 4/5] END ..booster=gbtree, n_estimators=305;, score=0.701 total time= 1.9min
# [CV 3/5] END booster=gblinear, n_estimators=298;, score=0.690 total time=   9.9s
# [CV 5/5] END booster=gblinear, n_estimators=299;, score=0.684 total time=   9.9s
# [CV 3/5] END booster=gblinear, n_estimators=301;, score=0.689 total time=  10.5s
# [CV 2/5] END booster=gblinear, n_estimators=303;, score=0.686 total time=  10.2s
# [CV 5/5] END booster=gblinear, n_estimators=304;, score=0.684 total time=  10.1s
# [CV 3/5] END ....booster=dart, n_estimators=295;, score=0.706 total time=12.0min
# [CV 1/5] END ....booster=dart, n_estimators=297;, score=0.705 total time=11.8min
# [CV 4/5] END ....booster=dart, n_estimators=298;, score=0.699 total time=12.8min
# [CV 2/5] END ....booster=dart, n_estimators=300;, score=0.708 total time=12.5min
# [CV 5/5] END ....booster=dart, n_estimators=301;, score=0.711 total time=11.9min
# [CV 3/5] END ....booster=dart, n_estimators=303;, score=0.705 total time=11.8min
# [CV 1/5] END ....booster=dart, n_estimators=305;, score=0.707 total time=11.1min
# [CV 3/5] END ..booster=gbtree, n_estimators=296;, score=0.707 total time= 1.9min
# [CV 1/5] END ..booster=gbtree, n_estimators=297;, score=0.705 total time= 1.9min
# [CV 2/5] END ..booster=gbtree, n_estimators=299;, score=0.707 total time= 1.9min
# [CV 1/5] END ..booster=gbtree, n_estimators=301;, score=0.706 total time= 1.9min
# [CV 4/5] END ..booster=gbtree, n_estimators=302;, score=0.699 total time= 1.9min
# [CV 3/5] END ..booster=gbtree, n_estimators=304;, score=0.704 total time= 1.9min
# [CV 5/5] END ..booster=gbtree, n_estimators=305;, score=0.709 total time= 1.9min
# [CV 4/5] END booster=gblinear, n_estimators=298;, score=0.689 total time=   9.8s
# [CV 2/5] END booster=gblinear, n_estimators=300;, score=0.686 total time=  10.0s
# [CV 5/5] END booster=gblinear, n_estimators=301;, score=0.684 total time=  10.3s
# [CV 3/5] END booster=gblinear, n_estimators=303;, score=0.689 total time=   9.9s
# [CV 1/5] END booster=gblinear, n_estimators=305;, score=0.694 total time=  10.1s
# [CV 4/5] END ....booster=dart, n_estimators=295;, score=0.699 total time=12.0min
# [CV 2/5] END ....booster=dart, n_estimators=297;, score=0.708 total time=11.8min
# [CV 5/5] END ....booster=dart, n_estimators=298;, score=0.711 total time=12.8min
# [CV 3/5] END ....booster=dart, n_estimators=300;, score=0.706 total time=12.5min
# [CV 1/5] END ....booster=dart, n_estimators=302;, score=0.705 total time=12.0min
# [CV 4/5] END ....booster=dart, n_estimators=303;, score=0.700 total time=11.8min
# [CV 2/5] END ....booster=dart, n_estimators=305;, score=0.707 total time=11.0min
# [CV 1/5] END ..booster=gbtree, n_estimators=296;, score=0.705 total time= 1.9min
# [CV 1/5] END ..booster=gbtree, n_estimators=298;, score=0.705 total time= 1.9min
# [CV 4/5] END ..booster=gbtree, n_estimators=299;, score=0.699 total time= 1.9min
# [CV 2/5] END ..booster=gbtree, n_estimators=301;, score=0.709 total time= 1.9min
# [CV 5/5] END ..booster=gbtree, n_estimators=302;, score=0.711 total time= 1.9min
# [CV 2/5] END ..booster=gbtree, n_estimators=304;, score=0.707 total time= 1.9min
# [CV 1/5] END booster=gblinear, n_estimators=295;, score=0.694 total time=   9.8s
# [CV 2/5] END booster=gblinear, n_estimators=295;, score=0.686 total time=   9.8s
# [CV 3/5] END booster=gblinear, n_estimators=295;, score=0.690 total time=   9.8s
# [CV 4/5] END booster=gblinear, n_estimators=295;, score=0.689 total time=   9.7s
# [CV 5/5] END booster=gblinear, n_estimators=295;, score=0.684 total time=   9.6s
# [CV 1/5] END booster=gblinear, n_estimators=296;, score=0.694 total time=   9.9s
# [CV 2/5] END booster=gblinear, n_estimators=296;, score=0.686 total time=   9.7s
# [CV 3/5] END booster=gblinear, n_estimators=296;, score=0.690 total time=   9.6s
# [CV 4/5] END booster=gblinear, n_estimators=296;, score=0.689 total time=  10.0s
# [CV 5/5] END booster=gblinear, n_estimators=296;, score=0.684 total time=  10.0s
# [CV 1/5] END booster=gblinear, n_estimators=297;, score=0.694 total time=  10.2s
# [CV 2/5] END booster=gblinear, n_estimators=297;, score=0.686 total time=  10.0s
# [CV 5/5] END booster=gblinear, n_estimators=298;, score=0.684 total time=   9.7s
# [CV 3/5] END booster=gblinear, n_estimators=300;, score=0.689 total time=   9.9s
# [CV 1/5] END booster=gblinear, n_estimators=302;, score=0.694 total time=  10.4s
# [CV 4/5] END booster=gblinear, n_estimators=303;, score=0.689 total time=   9.9s
# [CV 2/5] END booster=gblinear, n_estimators=305;, score=0.686 total time=  10.0s
# [CV 5/5] END ....booster=dart, n_estimators=295;, score=0.712 total time=12.0min
# [CV 3/5] END ....booster=dart, n_estimators=297;, score=0.706 total time=11.8min
# [CV 1/5] END ....booster=dart, n_estimators=299;, score=0.706 total time=12.8min
# [CV 4/5] END ....booster=dart, n_estimators=300;, score=0.698 total time=12.5min
# [CV 2/5] END ....booster=dart, n_estimators=302;, score=0.708 total time=12.0min
# [CV 5/5] END ....booster=dart, n_estimators=303;, score=0.710 total time=11.8min
# [CV 3/5] END ....booster=dart, n_estimators=305;, score=0.705 total time=11.0min
# [CV 3/5] END ..booster=gbtree, n_estimators=295;, score=0.706 total time= 1.9min
# [CV 4/5] END ..booster=gbtree, n_estimators=296;, score=0.699 total time= 1.9min
# [CV 2/5] END ..booster=gbtree, n_estimators=298;, score=0.707 total time= 1.9min
# [CV 5/5] END ..booster=gbtree, n_estimators=299;, score=0.711 total time= 1.8min
# [CV 3/5] END ..booster=gbtree, n_estimators=301;, score=0.706 total time= 1.9min
# [CV 1/5] END ..booster=gbtree, n_estimators=303;, score=0.705 total time= 1.9min
# [CV 4/5] END ..booster=gbtree, n_estimators=304;, score=0.699 total time= 1.9min
# [CV 3/5] END booster=gblinear, n_estimators=297;, score=0.690 total time=   9.9s
# [CV 1/5] END booster=gblinear, n_estimators=299;, score=0.694 total time=   9.9s
# [CV 4/5] END booster=gblinear, n_estimators=300;, score=0.689 total time=  10.2s
# [CV 2/5] END booster=gblinear, n_estimators=302;, score=0.686 total time=  10.2s
# [CV 5/5] END booster=gblinear, n_estimators=303;, score=0.684 total time=   9.9s
# [CV 3/5] END booster=gblinear, n_estimators=305;, score=0.689 total time=  10.1s
# [CV 1/5] END ....booster=dart, n_estimators=296;, score=0.705 total time=12.0min
# [CV 4/5] END ....booster=dart, n_estimators=297;, score=0.699 total time=11.9min
# [CV 3/5] END ....booster=dart, n_estimators=299;, score=0.705 total time=12.8min
# [CV 5/5] END ....booster=dart, n_estimators=300;, score=0.711 total time=12.5min
# [CV 3/5] END ....booster=dart, n_estimators=302;, score=0.705 total time=12.0min
# [CV 1/5] END ....booster=dart, n_estimators=304;, score=0.707 total time=11.9min
# [CV 4/5] END ....booster=dart, n_estimators=305;, score=0.701 total time=10.9min
# [CV 2/5] END ..booster=gbtree, n_estimators=295;, score=0.708 total time= 1.9min
# [CV 5/5] END ..booster=gbtree, n_estimators=296;, score=0.713 total time= 1.9min
# [CV 3/5] END ..booster=gbtree, n_estimators=298;, score=0.706 total time= 1.9min
# [CV 1/5] END ..booster=gbtree, n_estimators=300;, score=0.706 total time= 1.9min
# [CV 4/5] END ..booster=gbtree, n_estimators=301;, score=0.698 total time= 1.9min
# [CV 2/5] END ..booster=gbtree, n_estimators=303;, score=0.707 total time= 1.9min
# [CV 5/5] END ..booster=gbtree, n_estimators=304;, score=0.712 total time= 1.9min
# [CV 4/5] END booster=gblinear, n_estimators=297;, score=0.689 total time=   9.9s
# [CV 2/5] END booster=gblinear, n_estimators=299;, score=0.686 total time=   9.9s
# [CV 5/5] END booster=gblinear, n_estimators=300;, score=0.684 total time=  10.2s
# [CV 3/5] END booster=gblinear, n_estimators=302;, score=0.689 total time=  10.2s
# [CV 1/5] END booster=gblinear, n_estimators=304;, score=0.694 total time=  10.1s
# [CV 4/5] END booster=gblinear, n_estimators=305;, score=0.689 total time=  10.0s
# [CV 2/5] END ....booster=dart, n_estimators=296;, score=0.708 total time=12.0min
# [CV 5/5] END ....booster=dart, n_estimators=297;, score=0.711 total time=11.8min
# [CV 2/5] END ....booster=dart, n_estimators=299;, score=0.707 total time=12.9min
# [CV 1/5] END ....booster=dart, n_estimators=301;, score=0.706 total time=12.5min
# [CV 4/5] END ....booster=dart, n_estimators=302;, score=0.699 total time=11.9min
# [CV 2/5] END ....booster=dart, n_estimators=304;, score=0.707 total time=11.9min
# [CV 5/5] END ....booster=dart, n_estimators=305;, score=0.709 total time=10.9min

# %%
grid_xgb.best_params_
# Out:
# {'booster': 'gbtree', 'n_estimators': 296}

# %% [markdown]
# From the two grid searches that we have done, we have found the best parameters to be:
# - `n_estimators` = 296
# - `max_depth` = 1
# - `booster` = gbtree

# %%
final_xgb = XGBClassifier(max_depth=1, n_estimators=296, booster='gbtree')

final_xgb.fit(X_train_ss, y_train)

final_xgb.score(X_train_ss, y_train)
# Out:
# 0.7325356125356125

# %%
final_xgb.score(X_val_ss, y_val)
# Out:
# 0.6853230523796863

# %%
final_xgb.score(X_test_ss, y_test)
# Out:
# 0.6878838637632607

# %% [markdown]
# Not so great results on the validation and testing sets, but let's take a look at our evaluation metrics:

# %%
add_results(final_xgb, model_comparison_df, X_test_ss, y_test, 'Tuned XGBoost', 'max_depth=1, n_estimators=296')
# Out:
#         Model Instance                    description  precision    recall  \
# 0      DT_w_predictors                 First DT Model   0.888055  0.926638
# 1          DT_w_tuning                Second DT Model   0.710857  0.894444
# 2  Tuned Random Forest                 first tuned RF   0.708951  0.878917
# 3    Gradient Boosting                 out of the box   0.777580  0.745014
# 4        First XGBoost                 out of the box   0.751989  0.767521
# 5        First XGBoost                 out of the box   0.769559  0.745442
# 6        Tuned XGBoost  max_depth=1, n_estimators=296   0.769559  0.745442
#
#          F1
# 0  0.906936
# 1  0.792153
# 2  0.784837
# 3  0.760949
# 4  0.759676
# 5  0.757308
# 6  0.757308

# %% [markdown]
# Not bad! That's one of our better performing models so far. Let's see where the model went wrong with the confusion matrix:

# %%
plot_confusion_matrix(final_xgb, X_test_ss, y_test, cmap='Reds');

# %% [markdown]
# That's interesting, this model had more false negatives than false positives which is something that we haven't really seen yet. We could try and tune the hyperparameters of this model more, as this model does respond well to fine hyperparameter tuning, but for now we will leave it here. The next model that we will try is Logistic Regression. A staple baseline model.

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# We will want to loop over various values for `C` which is the inverse of the regularization strength.

# %%
cs = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100] #Values to loop over
train_acc = []
val_acc = []

for c in cs:
    
    # Instantiate the model
    logit = LogisticRegression(C=c)
    
    # Fit the model
    logit.fit(X_train_ss, y_train)
    
    # Score the model and append to the respective lists
    train_acc.append(logit.score(X_train_ss, y_train))
    val_acc.append(logit.score(X_val_ss, y_val))

# %% [markdown]
# Now we can plot these results:

# %%
plt.figure()
plt.plot(cs, train_acc, label='train', marker='o') #plotting train accuracies
plt.plot(cs, val_acc, label='val', marker='o') #plotting validation accuracies
plt.legend()
plt.ylabel('Accuracy Score')
plt.xlabel('C Regularization Parameter')
plt.xscale('log')
plt.show()

# %% [markdown]
# That has been the worst performing model we have seen thus far. We will add these results to our DataFrame, but we will not be pursuing this model any further.

# %%
add_results(logit, model_comparison_df, X_test_ss, y_test, 'First Logistic Regression', 'tuned C only')
# Out:
#               Model Instance                    description  precision  \
# 0            DT_w_predictors                 First DT Model   0.888055
# 1                DT_w_tuning                Second DT Model   0.710857
# 2        Tuned Random Forest                 first tuned RF   0.708951
# 3          Gradient Boosting                 out of the box   0.777580
# 4              First XGBoost                 out of the box   0.751989
# 5              First XGBoost                 out of the box   0.769559
# 6              Tuned XGBoost  max_depth=1, n_estimators=296   0.769559
# 7  First Logistic Regression                   tuned C only   0.585827
#
#      recall        F1
# 0  0.926638  0.906936
# 1  0.894444  0.792153
# 2  0.878917  0.784837
# 3  0.745014  0.760949
# 4  0.767521  0.759676
# 5  0.745442  0.757308
# 6  0.745442  0.757308
# 7  0.052991  0.097191

# %% [markdown]
# Let's look at the confusion matrix for Logistic Regression

# %%
plot_confusion_matrix(logit, X_test_ss, y_test, cmap='Reds');

# %% [markdown]
# Wow, that must be the highest false negative rate that we have seen so far. This model was not able to accurately predict the positive class very well at all. It did do pretty well on predicting true negatives however. If there was a way to increase the true positive rate while maintaning the true negative rate, this model could be looked into further.
#
# -----------
#
# Another common model that is often used for classification is support vector machines. We will implement that model here.

# %% [markdown]
# ## Support Vector Machines

# %% [markdown]
# We will try this model using the kernel trick. Which is a way for a SVM model to identify non-linear relationships. More information on the kernel trick can be found here: https://en.wikipedia.org/wiki/Kernel_method

# %%
from sklearn.svm import SVC
# instantiating two different models, each with a different kernel
my_RBF_kernel_SVM = SVC(kernel='rbf') # the default kernel is a Radial Basis Function transformation
my_linear_kernel_SVM = SVC(kernel='linear')

# %%
#Fit the data
my_linear_kernel_SVM.fit(X_train_ss, y_train)

#Get the score
print(f"Linear SVM score (train): {my_linear_kernel_SVM.score(X_train_ss ,y_train)}")
print(f"Linear SVM score (validation): {my_linear_kernel_SVM.score(X_val_ss, y_val)}")
# Out:
# Linear SVM score (train): 0.7051282051282052
# Linear SVM score (validation): 0.37303908534964103

# %% [markdown]
# That might be the worst score we have seen yet on the validation set. Let's see how it does on the testing set:

# %%
my_linear_kernel_SVM.score(X_test_ss, y_test)
# Out:
# 0.36795086543830263

# %% [markdown]
# Still not great results. Nonetheless, we will still add this model to our DataFrame.

# %%
add_results(my_linear_kernel_SVM, model_comparison_df, X_test_ss, y_test, 'SVM Linear Kernel', 'out of the box')
# Out:
#               Model Instance                    description  precision  \
# 0            DT_w_predictors                 First DT Model   0.888055
# 1                DT_w_tuning                Second DT Model   0.710857
# 2        Tuned Random Forest                 first tuned RF   0.708951
# 3          Gradient Boosting                 out of the box   0.777580
# 4              First XGBoost                 out of the box   0.751989
# 5              First XGBoost                 out of the box   0.769559
# 6              Tuned XGBoost  max_depth=1, n_estimators=296   0.769559
# 7  First Logistic Regression                   tuned C only   0.585827
# 8          SVM Linear Kernel                 out of the box   0.692568
#
#      recall        F1
# 0  0.926638  0.906936
# 1  0.894444  0.792153
# 2  0.878917  0.784837
# 3  0.745014  0.760949
# 4  0.767521  0.759676
# 5  0.745442  0.757308
# 6  0.745442  0.757308
# 7  0.052991  0.097191
# 8  0.058405  0.107725

# %% [markdown]
# And to look at the confusion matrix:

# %%
plot_confusion_matrix(my_linear_kernel_SVM, X_test_ss, y_test, cmap='Reds');

# %% [markdown]
# Interesting, this model is biased towards predicting 0 for most values. It did pretty well in predicting true negatives but also had a very high false negative rate. With only 410 true positives detected, and the extremely long runtime of this model, this model is not a good model to use for our case.

# %% [markdown]
# Let's try the other SVM that was created above:

# %%
my_RBF_kernel_SVM.fit(X_train_ss, y_train)

train_score = my_RBF_kernel_SVM.score(X_train_ss, y_train)
val_score = my_RBF_kernel_SVM.score(X_val_ss, y_val)

# %% [markdown]
# And now to print the results:

# %%
print(train_score)
print(val_score)
# Out:
# 0.7655840455840456
# 0.6532837011433129

# %% [markdown]
# That is much better than the previous SVM model, however this model seems to be overfitting a bit. Let's see how it does on the testing set:

# %%
my_RBF_kernel_SVM.score(X_test_ss, y_test)
# Out:
# 0.6532663316582915

# %% [markdown]
# That is pretty much in line with our baseline accuracy score. Let's look at the other metrics and the confusion matrix:

# %%
add_results(my_RBF_kernel_SVM, model_comparison_df, X_test_ss, y_test, 'SVM RBF Kernel', 'out of the box')
# Out:
#               Model Instance                    description  precision  \
# 0            DT_w_predictors                 First DT Model   0.888055
# 1                DT_w_tuning                Second DT Model   0.710857
# 2        Tuned Random Forest                 first tuned RF   0.708951
# 3          Gradient Boosting                 out of the box   0.777580
# 4              First XGBoost                 out of the box   0.751989
# 5              First XGBoost                 out of the box   0.769559
# 6              Tuned XGBoost  max_depth=1, n_estimators=296   0.769559
# 7  First Logistic Regression                   tuned C only   0.585827
# 8          SVM Linear Kernel                 out of the box   0.692568
# 9             SVM RBF Kernel                 out of the box   0.653266
#
#      recall        F1
# 0  0.926638  0.906936
# 1  0.894444  0.792153
# 2  0.878917  0.784837
# 3  0.745014  0.760949
# 4  0.767521  0.759676
# 5  0.745442  0.757308
# 6  0.745442  0.757308
# 7  0.052991  0.097191
# 8  0.058405  0.107725
# 9  1.000000  0.790274

# %% [markdown]
# Wow, that got a perfect recall! Let's see the confusion matrix:

# %%
plot_confusion_matrix(my_RBF_kernel_SVM, X_test_ss, y_test, cmap='Reds');

# %% [markdown]
# **Interpretation**: This model did not predict any actual 0 values correctly, nor did it predict any False Negatives. A model that only predicts the positive class is perfectly in line with our baseline accuracy, which is not what we are after.
#
# -------
#
# Due to the computationally expensive runtimes, and subpar results, we will not be pursuing support vector machines anymore in this notebook. Let's try a simple neural network for our next model.

# %% [markdown]
# ## Deep Learning

# %% [markdown]
# For this model, we will be using TensorFlow. Another popular library for neural networks is Pytorch, but for ease of use, we will be using tensorflow here:

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# For our data to work in a tensorflow model, we will have to convert the X datasets to float datatypes, and reshape our y datasets.

# %%
X_train_nn = np.array(X_train_ss, dtype=np.float32) # changing datatype
y_train_nn = np.array(y_train, dtype=np.float32).reshape((-1, 1)) #reshaping the array

# applying the above to the rest of our data
X_test_nn = np.array(X_test_ss, dtype=np.float32)
y_test_nn = np.array(y_test, dtype=np.float32).reshape((-1, 1))
X_val_nn = np.array(X_val_ss, dtype=np.float32)
y_val_nn = np.array(y_val, dtype=np.float32).reshape((-1, 1))

# %% [markdown]
# Let's look at the shape of `y_train` to ensure that our changes were implemented.

# %%
y_train_nn.shape
# Out:
# (17550, 1)

# %% [markdown]
# Looks like that has worked, let's set up our model.

# %%
model = keras.Sequential() # Standard model type for a simple neural network

# Declare the hidden layers
model.add(layers.Dense(30, activation="relu")) # Adding dense layers with the relu activation function
model.add(layers.Dense(60, activation="relu"))
model.add(layers.Dense(30, activation="relu"))
model.add(layers.Dense(29, activation="relu"))
model.add(layers.Dense(28, activation="relu"))
model.add(layers.Dense(27, activation="relu"))
model.add(layers.Dense(26, activation="relu"))


# Declare the output layer - one output for predicting the probability of class 1
model.add(layers.Dense(1, activation="sigmoid"))
# Out:
# 2022-09-25 21:08:01.426058: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(
    # Optimizer
    optimizer='adam',  
    # Loss function to minimize
    loss='binary_crossentropy', # standard choice for binary classification with 1 output node
    # Metric used to evaluate model
    metrics=['binary_accuracy']
)

# %% [markdown]
# Now that our model is set up and compiled, we can fun our model using the `fit` method:

# %%
history = model.fit(X_train_nn, y_train_nn, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 549/549 [==============================] - 1s 794us/step - loss: 0.6075 - binary_accuracy: 0.6662
# Epoch 2/100
# 549/549 [==============================] - 0s 799us/step - loss: 0.5601 - binary_accuracy: 0.7036
# Epoch 3/100
# 549/549 [==============================] - 0s 783us/step - loss: 0.5360 - binary_accuracy: 0.7277
# Epoch 4/100
# 549/549 [==============================] - 0s 782us/step - loss: 0.5153 - binary_accuracy: 0.7428
# Epoch 5/100
# 549/549 [==============================] - 0s 785us/step - loss: 0.4931 - binary_accuracy: 0.7630
# Epoch 6/100
# 549/549 [==============================] - 0s 781us/step - loss: 0.4705 - binary_accuracy: 0.7762
# Epoch 7/100
# 549/549 [==============================] - 0s 781us/step - loss: 0.4482 - binary_accuracy: 0.7944
# Epoch 8/100
# 549/549 [==============================] - 0s 822us/step - loss: 0.4221 - binary_accuracy: 0.8096
# Epoch 9/100
# 549/549 [==============================] - 0s 790us/step - loss: 0.4035 - binary_accuracy: 0.8197
# Epoch 10/100
# 549/549 [==============================] - 0s 805us/step - loss: 0.3800 - binary_accuracy: 0.8344
# Epoch 11/100
# 549/549 [==============================] - 0s 814us/step - loss: 0.3612 - binary_accuracy: 0.8448
# Epoch 12/100
# 549/549 [==============================] - 0s 794us/step - loss: 0.3423 - binary_accuracy: 0.8567
# Epoch 13/100
# 549/549 [==============================] - 0s 802us/step - loss: 0.3212 - binary_accuracy: 0.8668
# Epoch 14/100
# 549/549 [==============================] - 0s 815us/step - loss: 0.3067 - binary_accuracy: 0.8746
# Epoch 15/100
# 549/549 [==============================] - 0s 808us/step - loss: 0.2935 - binary_accuracy: 0.8818
# Epoch 16/100
# 549/549 [==============================] - 0s 907us/step - loss: 0.2814 - binary_accuracy: 0.8844
# Epoch 17/100
# 549/549 [==============================] - 0s 794us/step - loss: 0.2666 - binary_accuracy: 0.8926
# Epoch 18/100
# 549/549 [==============================] - 0s 788us/step - loss: 0.2597 - binary_accuracy: 0.8952
# Epoch 19/100
# 549/549 [==============================] - 0s 784us/step - loss: 0.2466 - binary_accuracy: 0.9050
# Epoch 20/100
# 549/549 [==============================] - 0s 789us/step - loss: 0.2400 - binary_accuracy: 0.9040
# Epoch 21/100
# 549/549 [==============================] - 0s 799us/step - loss: 0.2253 - binary_accuracy: 0.9120
# Epoch 22/100
# 549/549 [==============================] - 0s 786us/step - loss: 0.2142 - binary_accuracy: 0.9183
# Epoch 23/100
# 549/549 [==============================] - 0s 791us/step - loss: 0.2192 - binary_accuracy: 0.9173
# Epoch 24/100
# 549/549 [==============================] - 0s 796us/step - loss: 0.2016 - binary_accuracy: 0.9245
# Epoch 25/100
# 549/549 [==============================] - 0s 808us/step - loss: 0.1962 - binary_accuracy: 0.9247
# Epoch 26/100
# 549/549 [==============================] - 0s 794us/step - loss: 0.1989 - binary_accuracy: 0.9228
# Epoch 27/100
# 549/549 [==============================] - 0s 796us/step - loss: 0.1842 - binary_accuracy: 0.9307
# Epoch 28/100
# 549/549 [==============================] - 0s 824us/step - loss: 0.1766 - binary_accuracy: 0.9327
# Epoch 29/100
# 549/549 [==============================] - 0s 785us/step - loss: 0.1729 - binary_accuracy: 0.9334
# Epoch 30/100
# 549/549 [==============================] - 0s 813us/step - loss: 0.1703 - binary_accuracy: 0.9341
# Epoch 31/100
# 549/549 [==============================] - 0s 808us/step - loss: 0.1615 - binary_accuracy: 0.9397
# Epoch 32/100
# 549/549 [==============================] - 0s 804us/step - loss: 0.1659 - binary_accuracy: 0.9369
# Epoch 33/100
# 549/549 [==============================] - 0s 806us/step - loss: 0.1518 - binary_accuracy: 0.9436
# Epoch 34/100
# 549/549 [==============================] - 0s 814us/step - loss: 0.1503 - binary_accuracy: 0.9429
# Epoch 35/100
# 549/549 [==============================] - 0s 858us/step - loss: 0.1521 - binary_accuracy: 0.9426
# Epoch 36/100
# 549/549 [==============================] - 0s 844us/step - loss: 0.1475 - binary_accuracy: 0.9447
# Epoch 37/100
# 549/549 [==============================] - 0s 826us/step - loss: 0.1387 - binary_accuracy: 0.9496
# Epoch 38/100
# 549/549 [==============================] - 0s 803us/step - loss: 0.1404 - binary_accuracy: 0.9480
# Epoch 39/100
# 549/549 [==============================] - 0s 865us/step - loss: 0.1354 - binary_accuracy: 0.9496
# Epoch 40/100
# 549/549 [==============================] - 0s 840us/step - loss: 0.1289 - binary_accuracy: 0.9516
# Epoch 41/100
# 549/549 [==============================] - 0s 815us/step - loss: 0.1304 - binary_accuracy: 0.9506
# Epoch 42/100
# 549/549 [==============================] - 0s 864us/step - loss: 0.1288 - binary_accuracy: 0.9526
# Epoch 43/100
# 549/549 [==============================] - 0s 806us/step - loss: 0.1243 - binary_accuracy: 0.9552
# Epoch 44/100
# 549/549 [==============================] - 0s 801us/step - loss: 0.1270 - binary_accuracy: 0.9534
# Epoch 45/100
# 549/549 [==============================] - 0s 839us/step - loss: 0.1201 - binary_accuracy: 0.9568
# Epoch 46/100
# 549/549 [==============================] - 1s 928us/step - loss: 0.1176 - binary_accuracy: 0.9566
# Epoch 47/100
# 549/549 [==============================] - 0s 879us/step - loss: 0.1149 - binary_accuracy: 0.9572
# Epoch 48/100
# 549/549 [==============================] - 0s 859us/step - loss: 0.1165 - binary_accuracy: 0.9582
# Epoch 49/100
# 549/549 [==============================] - 0s 876us/step - loss: 0.1143 - binary_accuracy: 0.9591
# Epoch 50/100
# 549/549 [==============================] - 0s 818us/step - loss: 0.1044 - binary_accuracy: 0.9631
# Epoch 51/100
# 549/549 [==============================] - 0s 838us/step - loss: 0.1098 - binary_accuracy: 0.9586
# Epoch 52/100
# 549/549 [==============================] - 0s 830us/step - loss: 0.1091 - binary_accuracy: 0.9609
# Epoch 53/100
# 549/549 [==============================] - 0s 855us/step - loss: 0.1076 - binary_accuracy: 0.9592
# Epoch 54/100
# 549/549 [==============================] - 0s 855us/step - loss: 0.0967 - binary_accuracy: 0.9649
# Epoch 55/100
# 549/549 [==============================] - 0s 844us/step - loss: 0.1022 - binary_accuracy: 0.9620
# Epoch 56/100
# 549/549 [==============================] - 0s 843us/step - loss: 0.1077 - binary_accuracy: 0.9599
# Epoch 57/100
# 549/549 [==============================] - 0s 833us/step - loss: 0.0979 - binary_accuracy: 0.9623
# Epoch 58/100
# 549/549 [==============================] - 0s 875us/step - loss: 0.0936 - binary_accuracy: 0.9659
# Epoch 59/100
# 549/549 [==============================] - 0s 825us/step - loss: 0.0942 - binary_accuracy: 0.9655
# Epoch 60/100
# 549/549 [==============================] - 0s 807us/step - loss: 0.0936 - binary_accuracy: 0.9653
# Epoch 61/100
# 549/549 [==============================] - 0s 870us/step - loss: 0.0989 - binary_accuracy: 0.9639
# Epoch 62/100
# 549/549 [==============================] - 0s 843us/step - loss: 0.0846 - binary_accuracy: 0.9690
# Epoch 63/100
# 549/549 [==============================] - 0s 840us/step - loss: 0.0944 - binary_accuracy: 0.9646
# Epoch 64/100
# 549/549 [==============================] - 0s 845us/step - loss: 0.0915 - binary_accuracy: 0.9659
# Epoch 65/100
# 549/549 [==============================] - 0s 858us/step - loss: 0.0870 - binary_accuracy: 0.9685
# Epoch 66/100
# 549/549 [==============================] - 0s 804us/step - loss: 0.0875 - binary_accuracy: 0.9689
# Epoch 67/100
# 549/549 [==============================] - 0s 805us/step - loss: 0.0857 - binary_accuracy: 0.9689
# Epoch 68/100
# 549/549 [==============================] - 0s 858us/step - loss: 0.0814 - binary_accuracy: 0.9704
# Epoch 69/100
# 549/549 [==============================] - 0s 815us/step - loss: 0.0795 - binary_accuracy: 0.9716
# Epoch 70/100
# 549/549 [==============================] - 0s 830us/step - loss: 0.0809 - binary_accuracy: 0.9713
# Epoch 71/100
# 549/549 [==============================] - 0s 837us/step - loss: 0.0849 - binary_accuracy: 0.9684
# Epoch 72/100
# 549/549 [==============================] - 0s 813us/step - loss: 0.0805 - binary_accuracy: 0.9703
# Epoch 73/100
# 549/549 [==============================] - 0s 819us/step - loss: 0.0728 - binary_accuracy: 0.9746
# Epoch 74/100
# 549/549 [==============================] - 0s 817us/step - loss: 0.0751 - binary_accuracy: 0.9736
# Epoch 75/100
# 549/549 [==============================] - 0s 832us/step - loss: 0.0762 - binary_accuracy: 0.9709
# Epoch 76/100
# 549/549 [==============================] - 0s 856us/step - loss: 0.0719 - binary_accuracy: 0.9742
# Epoch 77/100
# 549/549 [==============================] - 0s 830us/step - loss: 0.0757 - binary_accuracy: 0.9724
# Epoch 78/100
# 549/549 [==============================] - 0s 841us/step - loss: 0.0713 - binary_accuracy: 0.9750
# Epoch 79/100
# 549/549 [==============================] - 0s 789us/step - loss: 0.0761 - binary_accuracy: 0.9725
# Epoch 80/100
# 549/549 [==============================] - 0s 815us/step - loss: 0.0726 - binary_accuracy: 0.9733
# Epoch 81/100
# 549/549 [==============================] - 0s 807us/step - loss: 0.0733 - binary_accuracy: 0.9736
# Epoch 82/100
# 549/549 [==============================] - 0s 825us/step - loss: 0.0712 - binary_accuracy: 0.9740
# Epoch 83/100
# 549/549 [==============================] - 0s 789us/step - loss: 0.0725 - binary_accuracy: 0.9740
# Epoch 84/100
# 549/549 [==============================] - 0s 795us/step - loss: 0.0731 - binary_accuracy: 0.9726
# Epoch 85/100
# 549/549 [==============================] - 0s 830us/step - loss: 0.0704 - binary_accuracy: 0.9741
# Epoch 86/100
# 549/549 [==============================] - 0s 792us/step - loss: 0.0628 - binary_accuracy: 0.9781
# Epoch 87/100
# 549/549 [==============================] - 0s 794us/step - loss: 0.0707 - binary_accuracy: 0.9750
# Epoch 88/100
# 549/549 [==============================] - 0s 808us/step - loss: 0.0592 - binary_accuracy: 0.9782
# Epoch 89/100
# 549/549 [==============================] - 0s 818us/step - loss: 0.0737 - binary_accuracy: 0.9733
# Epoch 90/100
# 549/549 [==============================] - 0s 808us/step - loss: 0.0657 - binary_accuracy: 0.9761
# Epoch 91/100
# 549/549 [==============================] - 0s 775us/step - loss: 0.0611 - binary_accuracy: 0.9766
# Epoch 92/100
# 549/549 [==============================] - 0s 808us/step - loss: 0.0634 - binary_accuracy: 0.9773
# Epoch 93/100
# 549/549 [==============================] - 0s 829us/step - loss: 0.0680 - binary_accuracy: 0.9750
# Epoch 94/100
# 549/549 [==============================] - 0s 819us/step - loss: 0.0659 - binary_accuracy: 0.9770
# Epoch 95/100
# 549/549 [==============================] - 0s 793us/step - loss: 0.0556 - binary_accuracy: 0.9794
# Epoch 96/100
# 549/549 [==============================] - 0s 827us/step - loss: 0.0645 - binary_accuracy: 0.9780
# Epoch 97/100
# 549/549 [==============================] - 0s 779us/step - loss: 0.0610 - binary_accuracy: 0.9788
# Epoch 98/100
# 549/549 [==============================] - 0s 798us/step - loss: 0.0627 - binary_accuracy: 0.9781
# Epoch 99/100
# 549/549 [==============================] - 0s 788us/step - loss: 0.0612 - binary_accuracy: 0.9802
# Epoch 100/100
# 549/549 [==============================] - 0s 784us/step - loss: 0.0653 - binary_accuracy: 0.9753

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                13740
#
#  dense_1 (Dense)             (None, 60)                1860
#
#  dense_2 (Dense)             (None, 30)                1830
#
#  dense_3 (Dense)             (None, 29)                899
#
#  dense_4 (Dense)             (None, 28)                840
#
#  dense_5 (Dense)             (None, 27)                783
#
#  dense_6 (Dense)             (None, 26)                728
#
#  dense_7 (Dense)             (None, 1)                 27
#
# =================================================================
# Total params: 20,707
# Trainable params: 20,707
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Evaluate the network
train_accuracy = history.history["binary_accuracy"][-1]
result = model.evaluate(X_test_ss, y_test, verbose=0)

print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {result[1]:.4f}") 

# Generate predictions
predictions = model.predict(X_test_ss)
# Out:
# Train Accuracy: 0.9753
# Test Accuracy: 0.3497

# %% [markdown]
# That model is way overfitting and we are not even predicting the baseline for the test set. It is also predicting that almost all of the values are 1. Let's run it again, but with our validation data and a few tweaks. First we will look at the confusion matrix and add the results of this model to our model evaluation DataFrame

# %%
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.math import confusion_matrix

# %%
import seaborn as sns
def plot_cm(labels, predictions, p=0.5):
  cm = confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

# %%
cm = confusion_matrix(y_test, predictions>0.5)
plot_cm(y_test, predictions)

# %% [markdown]
# This model is almost the opposite of our SVM models. This model leaned heavily towards predicting the negative class, with very little values being predicted as positive, whether that be false positives or true positives.
#
# -------
#
# To add these values to our DataFrame, we will have to calculate the precision, recall and F1 Score manually.

# %%
np.sum(cm[0][0]) #True negatives
# Out:
# 3441

# %%
np.sum(cm[1][1]) #True positives
# Out:
# 317

# %%
np.sum(cm[0][1]) #False positives
# Out:
# 285

# %%
np.sum(cm[1][0]) #False negatives
# Out:
# 6703

# %% [markdown]
# Below we define the manual functions for our precision, recall and F1 score.

# %%
def precision(cm):
    tn = np.sum(cm[0][0]) #True negatives
    fp = np.sum(cm[0][1]) #False positives
    fn = np.sum(cm[1][0]) #False negatives
    tp = np.sum(cm[1][1]) # true positives
    
    return (tp) / (tp+fp) # Precision formula

# %%
def recall(cm):
    tn = np.sum(cm[0][0]) #True negatives
    fp = np.sum(cm[0][1]) #False positives
    fn = np.sum(cm[1][0]) #False negatives
    tp = np.sum(cm[1][1]) # true positives
    
    return (tp)/(tp+fn) # recall score

# %%
def f1score(precision, recall):
    return (2*((precision*recall)/(precision+recall))) # formula for f1 score

# %%
precision = precision(cm)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [114], in <cell line: 1>()
# ----> 1 precision = precision(cm)
#
# TypeError: 'numpy.float64' object is not callable

# %%
recall = recall(cm)

# %%
f1score = f1score(precision, recall)
f1score
# Out:
# 0.08318026764628705

# %% [markdown]
# Let's put these results into a list, since we cannot use them in our custom function to add them to our dataframe.

# %%
data = ['First Neural Net', '7 hidden layers, various nodes each, 100 epochs', precision,
       recall, f1score]
data
# Out:
# ['First Neural Net',
#  '7 hidden layers, various nodes each, 100 epochs',
#  0.526578073089701,
#  0.045156695156695154,
#  0.08318026764628705]

# %% [markdown]
# We can add these values to our dataframe by appending them as the last row.

# %%
model_comparison_df.loc[len(model_comparison_df)] = data
model_comparison_df
# Out:
#                Model Instance  \
# 0             DT_w_predictors
# 1                 DT_w_tuning
# 2         Tuned Random Forest
# 3           Gradient Boosting
# 4               First XGBoost
# 5               First XGBoost
# 6               Tuned XGBoost
# 7   First Logistic Regression
# 8           SVM Linear Kernel
# 9              SVM RBF Kernel
# 10           First Neural Net
# 11           First Neural Net
#
#                                         description  precision    recall  \
# 0                                    First DT Model   0.888055  0.926638
# 1                                   Second DT Model   0.710857  0.894444
# 2                                    first tuned RF   0.708951  0.878917
# 3                                    out of the box   0.777580  0.745014
# 4                                    out of the box   0.751989  0.767521
# 5                                    out of the box   0.769559  0.745442
# 6                     max_depth=1, n_estimators=296   0.769559  0.745442
# 7                                      tuned C only   0.585827  0.052991
# 8                                    out of the box   0.692568  0.058405
# 9                                    out of the box   0.653266  1.000000
# 10       7 hidden layers, 30 nodes each, 100 epochs   0.526578  0.045157
# 11  7 hidden layers, various nodes each, 100 epochs   0.526578  0.045157
#
#           F1
# 0   0.906936
# 1   0.792153
# 2   0.784837
# 3   0.760949
# 4   0.759676
# 5   0.757308
# 6   0.757308
# 7   0.097191
# 8   0.107725
# 9   0.790274
# 10  0.083180
# 11  0.083180

# %% [markdown]
# It is interesting to note the insanely low recall score for this model. If there was more time for this project, neural networks could be explored more, however we already have models that perform better and will use those for our final model.

# %% [markdown]
# ## Model Selection

# %% [markdown]
# Overall we are using three metrics to gauge our models:
#
# - Precision: The fraction of positive predictions that are correct. Maximizing this limits false positives
# - Recall: The fraction of positive cases that were predicted as positive. Maximizing this limits false negatives
# - F1 Score: The harmonic mean of precision and recall, important if you care about the positive class in both precision and recall equally
#
# ------
#
# **Remember: Our goal of the project is to identify hosts that have bad review scores**
#
# With the imbalance of the data, It is more important to limit the amount of false positives, or in more general terms: hosts who have bad review scores that are predicted to have good review scores.
#
# -----
#
# With that being said, the model that maximized precision (outside of the first model which had the collinear predictors), and F1 Score second was the Gradient Boosting model that was ran. This is the model that we will select.

# %%
model_comparison_df.sort_values(by=['precision', 'F1'], ascending=False)
# Out:
#                Model Instance  \
# 0             DT_w_predictors
# 3           Gradient Boosting
# 5               First XGBoost
# 6               Tuned XGBoost
# 4               First XGBoost
# 1                 DT_w_tuning
# 2         Tuned Random Forest
# 8           SVM Linear Kernel
# 9              SVM RBF Kernel
# 7   First Logistic Regression
# 10           First Neural Net
# 11           First Neural Net
#
#                                         description  precision    recall  \
# 0                                    First DT Model   0.888055  0.926638
# 3                                    out of the box   0.777580  0.745014
# 5                                    out of the box   0.769559  0.745442
# 6                     max_depth=1, n_estimators=296   0.769559  0.745442
# 4                                    out of the box   0.751989  0.767521
# 1                                   Second DT Model   0.710857  0.894444
# 2                                    first tuned RF   0.708951  0.878917
# 8                                    out of the box   0.692568  0.058405
# 9                                    out of the box   0.653266  1.000000
# 7                                      tuned C only   0.585827  0.052991
# 10       7 hidden layers, 30 nodes each, 100 epochs   0.526578  0.045157
# 11  7 hidden layers, various nodes each, 100 epochs   0.526578  0.045157
#
#           F1
# 0   0.906936
# 3   0.760949
# 5   0.757308
# 6   0.757308
# 4   0.759676
# 1   0.792153
# 2   0.784837
# 8   0.107725
# 9   0.790274
# 7   0.097191
# 10  0.083180
# 11  0.083180

# %% [markdown]
# We will try to tune the hyperparameters of this model since our first instance was just out of the box.

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
grad_boost = GradientBoostingClassifier(random_state=10)

grad_boost.fit(X_train_ss, y_train)

train_score = grad_boost.score(X_train_ss, y_train)
val_score = grad_boost.score(X_val_ss, y_val)

# %%
print(f'Training Score on Basic Gradient Boost Model: {train_score}')
print(f'Validation Score on Basic Gradient Boost Model: {val_score}')
# Out:
# Training Score on Basic Gradient Boost Model: 0.7388603988603989
# Validation Score on Basic Gradient Boost Model: 0.6979526721616591

# %% [markdown]
# Let's see how this model does on the testing data again:

# %%
grad_boost.score(X_test_ss, y_test)
# Out:
# 0.6942117997394379

# %%
plot_confusion_matrix(grad_boost, X_test_ss, y_test, cmap='Reds');

# %% [markdown]
# All of this data has already been seen in the earlier part of the notebook, we will continue onto hyperparameter optimization here.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score, accuracy_score

# %%
gbm1 = GradientBoostingClassifier(random_state=10)

# %% [markdown]
# Below we will run a cross validation on this model, and look at what features are the most important predictors for this model. We will also use the roc_auc score here, which provides an aggregate measure of performance across all possible classification thresholds.

# %%
    #Fit the algorithm on the data
gbm1.fit(X_train_ss, y_train)
        
    #Predict training set:
train_predictions = gbm1.predict(X_train_ss)
train_predprob = gbm1.predict_proba(X_train_ss)[:,1]
    
    #Perform cross-validation:

cv_score = cross_val_score(gbm1, X_train_ss, y_train, cv=5, scoring='roc_auc')
    
    #Print model report:
print("\nModel Report")
print("Accuracy : %.4g" % accuracy_score(y_train, train_predictions))
print("AUC Score (Train): %f" % roc_auc_score(y_train, train_predprob))
    

print("CV Score : Mean - %.7g | Std - %.7g | Min - %.7g | Max - %.7g" % (np.mean(cv_score),np.std(cv_score),np.min(cv_score),np.max(cv_score)))
# Out:
# Model Report
# Accuracy : 0.7389
# AUC Score (Train): 0.797373
# CV Score : Mean - 0.7571295 | Std - 0.007769507 | Min - 0.7489922 | Max - 0.7703589

# %%
gbm1.feature_importances_.shape
# Out:
# (457,)

# %% [markdown]
# Let's convert these feature importances to a series so we can eventually plot them:

# %%
feat_imp = pd.Series(gbm1.feature_importances_, X_train.columns).sort_values(ascending=False)
feat_imp
# Out:
# host_is_superhost                    0.273537
# calculated_host_listings_count       0.134520
# number_of_reviews                    0.075121
# host_since                           0.053616
# host_total_listings_count            0.048932
#                                        ...
# ohe__neighborhood_Port Morris        0.000000
# ohe__neighborhood_Port Ivory         0.000000
# ohe__neighborhood_Pelham Gardens     0.000000
# ohe__neighborhood_Pelham Bay Park    0.000000
# ohe__neighborhood_Silver Lake        0.000000
# Length: 457, dtype: float64

# %%
    #Print Feature Importance:
feat_imp = pd.Series(gbm1.feature_importances_, X_train.columns).sort_values(ascending=False)[:20]
feat_imp.plot(kind='bar', title='Feature Importances')
plt.ylabel('Feature Importance Score')
# Out:
# Text(0, 0.5, 'Feature Importance Score')

# %% [markdown]
# Some typical predictors here are expected. Things like `host_is_superhost`, `number_of_reviews` and `host_since` are all things that people might expect to influence a host's review score. It is interesting to see various amenities such as dishes & silverware, and hair dryers making the list.

# %% [markdown]
# Let's perform another grid search over some basic hyperparameters for this Gradient Boosting model.
#
# ------
#
# **PLEASE NOTE: The below cell takes a long time to finish running.**

# %%
parameters = {'n_estimators': [100, 300, 600, 900],
             'min_samples_split': [2, 4, 6, 8],
             'min_samples_leaf': [1, 3, 5]}
estimator=GradientBoostingClassifier(random_state=10)
clf = GridSearchCV(estimator, parameters, verbose=3)
clf.fit(X_train_ss, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.718 total time=  15.7s
# [CV 2/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.713 total time=  15.1s
# [CV 3/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.720 total time=  15.3s
# [CV 4/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.715 total time=  15.3s
# [CV 5/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.716 total time=  15.0s
# [CV 1/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.720 total time=  47.8s
# [CV 2/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.721 total time=  46.5s
# [CV 3/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.723 total time=  46.6s
# [CV 4/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.714 total time=  46.5s
# [CV 5/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.719 total time=  46.2s
# [CV 1/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=600;, score=0.724 total time= 1.6min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=600;, score=0.719 total time= 1.6min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=600;, score=0.724 total time= 1.6min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=600;, score=0.715 total time= 1.6min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=600;, score=0.721 total time= 1.6min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.717 total time= 2.4min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.715 total time= 2.4min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.723 total time= 2.4min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.713 total time= 2.4min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.717 total time= 2.4min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.718 total time=  15.7s
# [CV 2/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.714 total time=  15.9s
# [CV 3/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.721 total time=  15.2s
# [CV 4/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.715 total time=  15.2s
# [CV 5/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.717 total time=  15.4s
# [CV 1/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=300;, score=0.722 total time=  47.6s
# [CV 2/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=300;, score=0.719 total time=  47.2s
# [CV 3/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=300;, score=0.726 total time=  48.6s
# [CV 4/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=300;, score=0.717 total time=  48.7s
# [CV 5/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=300;, score=0.724 total time=  48.0s
# [CV 1/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=600;, score=0.718 total time= 1.6min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=600;, score=0.717 total time= 1.6min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=600;, score=0.725 total time= 1.6min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=600;, score=0.714 total time= 1.6min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=600;, score=0.727 total time= 1.6min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=900;, score=0.723 total time= 2.4min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=900;, score=0.723 total time= 2.4min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=900;, score=0.719 total time= 2.4min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=900;, score=0.713 total time= 2.4min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=4, n_estimators=900;, score=0.721 total time= 2.4min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.717 total time=  15.4s
# [CV 2/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.711 total time=  15.6s
# [CV 3/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.719 total time=  15.6s
# [CV 4/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.715 total time=  15.3s
# [CV 5/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.717 total time=  15.3s
# [CV 1/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=300;, score=0.719 total time=  47.7s
# [CV 2/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=300;, score=0.721 total time=  47.2s
# [CV 3/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=300;, score=0.723 total time=  47.9s
# [CV 4/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=300;, score=0.716 total time=  47.2s
# [CV 5/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=300;, score=0.720 total time=  47.9s
# [CV 1/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=600;, score=0.722 total time= 1.6min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=600;, score=0.716 total time= 1.6min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=600;, score=0.721 total time= 1.6min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=600;, score=0.713 total time= 1.6min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=600;, score=0.721 total time= 1.6min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=900;, score=0.715 total time= 2.4min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=900;, score=0.717 total time= 2.4min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=900;, score=0.719 total time= 2.4min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=900;, score=0.712 total time= 2.4min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=6, n_estimators=900;, score=0.717 total time= 2.4min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=0.717 total time=  15.2s
# [CV 2/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=0.711 total time=  15.5s
# [CV 3/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=0.720 total time=  15.8s
# [CV 4/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=0.711 total time=  15.3s
# [CV 5/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=0.714 total time=  15.3s
# [CV 1/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=300;, score=0.718 total time=  47.2s
# [CV 2/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=300;, score=0.718 total time=  48.6s
# [CV 3/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=300;, score=0.725 total time=  47.6s
# [CV 4/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=300;, score=0.713 total time=  47.2s
# [CV 5/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=300;, score=0.720 total time=  47.3s
# [CV 1/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=600;, score=0.722 total time= 1.6min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=600;, score=0.714 total time= 1.6min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=600;, score=0.723 total time= 1.6min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=600;, score=0.712 total time= 1.6min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=600;, score=0.725 total time= 1.6min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=900;, score=0.726 total time= 2.4min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=900;, score=0.715 total time= 2.4min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=900;, score=0.719 total time= 2.4min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=900;, score=0.714 total time= 2.4min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=900;, score=0.721 total time= 2.4min
# [CV 1/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.718 total time=  15.1s
# [CV 2/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.712 total time=  15.2s
# [CV 3/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.720 total time=  15.6s
# [CV 4/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.715 total time=  15.2s
# [CV 5/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.714 total time=  15.7s
# [CV 1/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=0.718 total time=  48.3s
# [CV 2/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=0.718 total time=  47.0s
# [CV 3/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=0.722 total time=  48.0s
# [CV 4/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=0.717 total time=  47.4s
# [CV 5/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=0.717 total time=  48.4s
# [CV 1/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=600;, score=0.719 total time= 1.6min
# [CV 2/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=600;, score=0.717 total time= 1.6min
# [CV 3/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=600;, score=0.722 total time= 1.6min
# [CV 4/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=600;, score=0.714 total time= 1.6min
# [CV 5/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=600;, score=0.726 total time= 1.6min
# [CV 1/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=900;, score=0.719 total time= 2.4min
# [CV 2/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=900;, score=0.716 total time= 2.4min
# [CV 3/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=900;, score=0.719 total time= 2.4min
# [CV 4/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=900;, score=0.708 total time= 2.4min
# [CV 5/5] END min_samples_leaf=3, min_samples_split=2, n_estimators=900;, score=0.722 total time= 2.4min
# [CV 1/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=100;, score=0.718 total time=  15.4s
# [CV 2/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=100;, score=0.712 total time=  15.2s
# [CV 3/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=100;, score=0.720 total time=  15.5s
# [CV 4/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=100;, score=0.715 total time=  15.7s
# [CV 5/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=100;, score=0.714 total time=  15.7s
# [CV 1/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=300;, score=0.718 total time=  46.7s
# [CV 2/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=300;, score=0.718 total time=  46.6s
# [CV 3/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=300;, score=0.722 total time=  46.6s
# [CV 4/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=300;, score=0.717 total time=  46.4s
# [CV 5/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=300;, score=0.717 total time=  46.6s
# [CV 1/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=600;, score=0.719 total time= 1.6min
# [CV 2/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=600;, score=0.717 total time= 1.6min
# [CV 3/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=600;, score=0.722 total time= 1.6min
# [CV 4/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=600;, score=0.714 total time= 1.6min
# [CV 5/5] END min_samples_leaf=3, min_samples_split=4, n_estimators=600;, score=0.726 total time= 1.6min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [134], in <cell line: 6>()
#       4 estimator=GradientBoostingClassifier(random_state=10)
#       5 clf = GridSearchCV(estimator, parameters, verbose=3)
# ----> 6 clf.fit(X_train_ss, y_train)
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/model_selection/_search.py:1379, in GridSearchCV._run_search(self, evaluate_candidates)
#    1377 def _run_search(self, evaluate_candidates):
#    1378     """Search all candidates in param_grid"""
# -> 1379     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/model_selection/_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:668, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     665     self._resize_state()
#     667 # fit the boosting stages
# --> 668 n_stages = self._fit_stages(
#     669     X,
#     670     y,
#     671     raw_predictions,
#     672     sample_weight,
#     673     self._rng,
#     674     X_val,
#     675     y_val,
#     676     sample_weight_val,
#     677     begin_at_stage,
#     678     monitor,
#     679 )
#     681 # change shape of arrays after fit (early-stopping or additional ests)
#     682 if n_stages != self.estimators_.shape[0]:
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:745, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     738     old_oob_score = loss_(
#     739         y[~sample_mask],
#     740         raw_predictions[~sample_mask],
#     741         sample_weight[~sample_mask],
#     742     )
#     744 # fit next stage of trees
# --> 745 raw_predictions = self._fit_stage(
#     746     i,
#     747     X,
#     748     y,
#     749     raw_predictions,
#     750     sample_weight,
#     751     sample_mask,
#     752     random_state,
#     753     X_csc,
#     754     X_csr,
#     755 )
#     757 # track deviance (= loss)
#     758 if do_oob:
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:247, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     244     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     246 X = X_csr if X_csr is not None else X
# --> 247 tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     249 # update tree leaves
#     250 loss.update_terminal_regions(
#     251     tree.tree_,
#     252     X,
#    (...)
#     259     k=k,
#     260 )
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/tree/_classes.py:1342, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1313 def fit(self, X, y, sample_weight=None, check_input=True):
#    1314     """Build a decision tree regressor from the training set (X, y).
#    1315
#    1316     Parameters
#    (...)
#    1339         Fitted estimator.
#    1340     """
# -> 1342     super().fit(
#    1343         X,
#    1344         y,
#    1345         sample_weight=sample_weight,
#    1346         check_input=check_input,
#    1347     )
#    1348     return self
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/tree/_classes.py:458, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     447 else:
#     448     builder = BestFirstTreeBuilder(
#     449         splitter,
#     450         min_samples_split,
#    (...)
#     455         self.min_impurity_decrease,
#     456     )
# --> 458 builder.build(self.tree_, X, y, sample_weight)
#     460 if self.n_outputs_ == 1 and is_classifier(self):
#     461     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
clf.best_score_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [135], in <cell line: 1>()
# ----> 1 clf.best_score_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_score_'

# %%
clf.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [136], in <cell line: 1>()
# ----> 1 clf.best_params_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %% [markdown]
# From the above, our best parameters are `n_estimators` = 300, `min_samples_leaf` = 1, `min_samples_split` = 4

# %%
gbm_tuned2 = GradientBoostingClassifier(learning_rate=0.1, n_estimators=300, 
                                        min_samples_leaf=1, min_samples_split=4)

    #Fit the algorithm on the data
gbm_tuned2.fit(X_train_ss, y_train)
        
    #Predict training set:
train_predictions = gbm_tuned2.predict(X_train_ss)
train_predprob = gbm_tuned2.predict_proba(X_train_ss)[:,1]
    
    #Perform cross-validation:

cv_score = cross_val_score(gbm_tuned2, X_train_ss, y_train, cv=5, scoring='roc_auc')
    
    #Print model report:
print("\nModel Report")
print("Accuracy : %.4g" % accuracy_score(y_train, train_predictions))
print("AUC Score (Train): %f" % roc_auc_score(y_train, train_predprob))
    

print("CV Score : Mean - %.7g | Std - %.7g | Min - %.7g | Max - %.7g" % (np.mean(cv_score),np.std(cv_score),np.min(cv_score),np.max(cv_score)))
# Out:
# Model Report
# Accuracy : 0.7767
# AUC Score (Train): 0.845669
# CV Score : Mean - 0.759466 | Std - 0.006721 | Min - 0.750195 | Max - 0.7695294

# %% [markdown]
# Let's again look at the top features:

# %%
    #Print Feature Importance:
feat_imp = pd.Series(gbm_tuned2.feature_importances_, X_train.columns).sort_values(ascending=False)[:20]
feat_imp.plot(kind='bar', title='Feature Importances')
plt.ylabel('Feature Importance Score')
#plt.xticks(rotation=75 )
plt.tight_layout()

#plt.savefig('foo.png', bbox_inches='tight')
plt.show()

# %%
gbm_tuned2.score(X_train_ss, y_train)
# Out:
# 0.7766951566951567

# %%
gbm_tuned2.score(X_test_ss, y_test)
# Out:
# 0.6925367578633911

# %%
add_results(gbm_tuned2, model_comparison_df, X_test_ss, y_test, 'Tuned Gradient Boost', 'n_estimators = 300, default learning rate')
# Out:
#                Model Instance  \
# 0             DT_w_predictors
# 1                 DT_w_tuning
# 2         Tuned Random Forest
# 3           Gradient Boosting
# 4               First XGBoost
# 5               First XGBoost
# 6               Tuned XGBoost
# 7   First Logistic Regression
# 8           SVM Linear Kernel
# 9              SVM RBF Kernel
# 10           First Neural Net
# 11           First Neural Net
# 12       Tuned Gradient Boost
#
#                                         description  precision    recall  \
# 0                                    First DT Model   0.888055  0.926638
# 1                                   Second DT Model   0.710857  0.894444
# 2                                    first tuned RF   0.708951  0.878917
# 3                                    out of the box   0.777580  0.745014
# 4                                    out of the box   0.751989  0.767521
# 5                                    out of the box   0.769559  0.745442
# 6                     max_depth=1, n_estimators=296   0.769559  0.745442
# 7                                      tuned C only   0.585827  0.052991
# 8                                    out of the box   0.692568  0.058405
# 9                                    out of the box   0.653266  1.000000
# 10       7 hidden layers, 30 nodes each, 100 epochs   0.526578  0.045157
# 11  7 hidden layers, various nodes each, 100 epochs   0.526578  0.045157
# 12        n_estimators = 300, default learning rate   0.745313  0.804131
#
#           F1
# 0   0.906936
# 1   0.792153
# 2   0.784837
# 3   0.760949
# 4   0.759676
# 5   0.757308
# 6   0.757308
# 7   0.097191
# 8   0.107725
# 9   0.790274
# 10  0.083180
# 11  0.083180
# 12  0.773606

# %% [markdown]
# That did pretty well! Let's try doing another grid search over some other parameters:

# %%
parameters = {'max_depth': range(5,16,2),
             'min_samples_split': range(4, 44, 10)}
estimator=GradientBoostingClassifier(n_estimators=300)
clf = GridSearchCV(estimator, parameters, verbose=2, n_jobs=-1)
clf.fit(X_train_ss, y_train)

# %%
clf.best_score_

# %%
clf.best_params_

# %% [markdown]
# From that run we found `max_depth` should be 5 and `min_samples_split` = 34.

# %%
gbm_tuned3 = GradientBoostingClassifier(learning_rate=0.1, n_estimators=300, 
                                        max_depth=5, min_samples_split=34)

    #Fit the algorithm on the data
gbm_tuned3.fit(X_train_ss, y_train)
        
    #Predict training set:
train_predictions = gbm_tuned3.predict(X_train_ss)
train_predprob = gbm_tuned3.predict_proba(X_train_ss)[:,1]
    
    #Perform cross-validation:

cv_score = cross_val_score(gbm_tuned3, X_train_ss, y_train, cv=5, scoring='roc_auc')
    
    #Print model report:
print("\nModel Report")
print("Accuracy : %.4g" % accuracy_score(y_train, train_predictions))
print("AUC Score (Train): %f" % roc_auc_score(y_train, train_predprob))
    

print("CV Score : Mean - %.7g | Std - %.7g | Min - %.7g | Max - %.7g" % (np.mean(cv_score),np.std(cv_score),np.min(cv_score),np.max(cv_score)))
# Out:
# Model Report
# Accuracy : 0.8555
# AUC Score (Train): 0.934034
# CV Score : Mean - 0.7564897 | Std - 0.006851928 | Min - 0.746093 | Max - 0.7665217

# %%
    #Print Feature Importance:
feat_imp = pd.Series(gbm_tuned3.feature_importances_, X_train.columns).sort_values(ascending=False)[:20]
feat_imp.plot(kind='bar', title='Feature Importances')
plt.ylabel('Feature Importance Score')
plt.show()

# %% [markdown]
# It is interesting to see some new variables made it into our chart. Things like `desc_away` and `desc_space` were not in our previous top features. Let's see how this model scored:

# %%
gbm_tuned3.score(X_train_ss, y_train)
# Out:
# 0.8554985754985756

# %%
gbm_tuned3.score(X_test_ss, y_test)
# Out:
# 0.5580681183696259

# %%
add_results(gbm_tuned3, model_comparison_df, X_test_ss, y_test, 'Tuned Gradient Boost (2)', 'n_estimators = 300, max_depth=5')
# Out:
#                Model Instance  \
# 0             DT_w_predictors
# 1                 DT_w_tuning
# 2         Tuned Random Forest
# 3           Gradient Boosting
# 4               First XGBoost
# 5               First XGBoost
# 6               Tuned XGBoost
# 7   First Logistic Regression
# 8           SVM Linear Kernel
# 9              SVM RBF Kernel
# 10           First Neural Net
# 11           First Neural Net
# 12       Tuned Gradient Boost
# 13   Tuned Gradient Boost (2)
#
#                                         description  precision    recall  \
# 0                                    First DT Model   0.888055  0.926638
# 1                                   Second DT Model   0.710857  0.894444
# 2                                    first tuned RF   0.708951  0.878917
# 3                                    out of the box   0.777580  0.745014
# 4                                    out of the box   0.751989  0.767521
# 5                                    out of the box   0.769559  0.745442
# 6                     max_depth=1, n_estimators=296   0.769559  0.745442
# 7                                      tuned C only   0.585827  0.052991
# 8                                    out of the box   0.692568  0.058405
# 9                                    out of the box   0.653266  1.000000
# 10       7 hidden layers, 30 nodes each, 100 epochs   0.526578  0.045157
# 11  7 hidden layers, various nodes each, 100 epochs   0.526578  0.045157
# 12        n_estimators = 300, default learning rate   0.745313  0.804131
# 13                  n_estimators = 300, max_depth=5   0.783238  0.447293
#
#           F1
# 0   0.906936
# 1   0.792153
# 2   0.784837
# 3   0.760949
# 4   0.759676
# 5   0.757308
# 6   0.757308
# 7   0.097191
# 8   0.107725
# 9   0.790274
# 10  0.083180
# 11  0.083180
# 12  0.773606
# 13  0.569408

# %%
plot_confusion_matrix(gbm_tuned3, X_test_ss, y_test, cmap='Reds');

# %% [markdown]
# That did not do as good as our first Gradient Boosting model and seems to be overfitting. One last attempt we can make with our modeling is to downsample the dominant class. We will do that below:

# %%
pd.Series(y_test).value_counts()
# Out:
# 1    7020
# 0    3726
# dtype: int64

# %%
pd.Series(y_train).value_counts()
# Out:
# 1    11465
# 0     6085
# dtype: int64

# %%
pd.Series(y_val).value_counts()
# Out:
# 1    4914
# 0    2608
# dtype: int64

# %% [markdown]
# Let's try one last approach. Now we will downsample the majority class so it has an equal distribution to the minority class and we will re-run our gradient boost model:

# %%
from sklearn.utils import resample

# %%
sample_range = np.arange(X_val.shape[0], X_train.shape[0]+1, 100)

# instantiating our empty lists
sample_size_list = []
train_set_scores = []
val_set_scores = []

# Looping over each value in our sample_range
for sample in sample_range:
    X_downsampled, y_downsampled = resample(X_train_ss, #Creating new sets based on our sample range, with replacement
                                           y_train,
                                           replace=True,
                                           n_samples=sample,
                                           random_state=42)
    

    # Model Fitting and scoring for KNN model
    gbm = GradientBoostingClassifier(learning_rate=0.1, n_estimators=300, 
                                        max_depth=5, min_samples_split=34, random_state=10)
    gbm.fit(X_downsampled, y_downsampled)
    train_score = gbm.score(X_train_ss, y_train)
    valscore = gbm.score(X_val_ss, y_val)
    
    # Calculating the model runtime
    runtime = end - start
    
    #Append values to the respective lists
    sample_size_list.append(sample)
    train_set_scores.append(train_score)
    val_set_scores.append(score)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [155], in <cell line: 9>()
#      17 # Model Fitting and scoring for KNN model
#      18 gbm = GradientBoostingClassifier(learning_rate=0.1, n_estimators=300,
#      19                                     max_depth=5, min_samples_split=34, random_state=10)
# ---> 20 gbm.fit(X_downsampled, y_downsampled)
#      21 train_score = gbm.score(X_train_ss, y_train)
#      22 valscore = gbm.score(X_val_ss, y_val)
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:668, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     665     self._resize_state()
#     667 # fit the boosting stages
# --> 668 n_stages = self._fit_stages(
#     669     X,
#     670     y,
#     671     raw_predictions,
#     672     sample_weight,
#     673     self._rng,
#     674     X_val,
#     675     y_val,
#     676     sample_weight_val,
#     677     begin_at_stage,
#     678     monitor,
#     679 )
#     681 # change shape of arrays after fit (early-stopping or additional ests)
#     682 if n_stages != self.estimators_.shape[0]:
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:745, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     738     old_oob_score = loss_(
#     739         y[~sample_mask],
#     740         raw_predictions[~sample_mask],
#     741         sample_weight[~sample_mask],
#     742     )
#     744 # fit next stage of trees
# --> 745 raw_predictions = self._fit_stage(
#     746     i,
#     747     X,
#     748     y,
#     749     raw_predictions,
#     750     sample_weight,
#     751     sample_mask,
#     752     random_state,
#     753     X_csc,
#     754     X_csr,
#     755 )
#     757 # track deviance (= loss)
#     758 if do_oob:
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:247, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     244     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     246 X = X_csr if X_csr is not None else X
# --> 247 tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     249 # update tree leaves
#     250 loss.update_terminal_regions(
#     251     tree.tree_,
#     252     X,
#    (...)
#     259     k=k,
#     260 )
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/tree/_classes.py:1342, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1313 def fit(self, X, y, sample_weight=None, check_input=True):
#    1314     """Build a decision tree regressor from the training set (X, y).
#    1315
#    1316     Parameters
#    (...)
#    1339         Fitted estimator.
#    1340     """
# -> 1342     super().fit(
#    1343         X,
#    1344         y,
#    1345         sample_weight=sample_weight,
#    1346         check_input=check_input,
#    1347     )
#    1348     return self
#
# File ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/sklearn/tree/_classes.py:458, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     447 else:
#     448     builder = BestFirstTreeBuilder(
#     449         splitter,
#     450         min_samples_split,
#    (...)
#     455         self.min_impurity_decrease,
#     456     )
# --> 458 builder.build(self.tree_, X, y, sample_weight)
#     460 if self.n_outputs_ == 1 and is_classifier(self):
#     461     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.plot(sample_size_list, val_set_scores)
plt.title('Validation Set Accuracy Score vs Downsampled y_val Data')
plt.ylabel("accuracy score")
plt.xlabel('Number of Observations')
plt.show()

# %%
best_val = np.argmax(val_set_scores)
sample_size_list[best_val]

# %% [markdown]
# So it looks like a sample size of 17,322 yielded the best results:

# %%
X_downsampled, y_downsampled = resample(X_train_ss, #Creating new sets based on our sample range, with replacement
                                           y_train,
                                           replace=True,
                                           n_samples=17322,
                                           random_state=42)
    

# Model Fitting and scoring for gbc model
gbm = GradientBoostingClassifier(learning_rate=0.1, n_estimators=300, 
                                        max_depth=5, min_samples_split=34)
gbm.fit(X_downsampled, y_downsampled)
score = gbm.score(X_test_ss, y_test)

# %%
score
# Out:
# 0.6805322910850549

# %%
add_results(gbm, model_comparison_df, X_test_ss, y_test, 'Downsampled Gradient Boost', 'n_estimators = 300, max_depth=5')
# Out:
#                 Model Instance  \
# 0              DT_w_predictors
# 1                  DT_w_tuning
# 2          Tuned Random Forest
# 3            Gradient Boosting
# 4                First XGBoost
# 5                First XGBoost
# 6                Tuned XGBoost
# 7    First Logistic Regression
# 8            SVM Linear Kernel
# 9               SVM RBF Kernel
# 10            First Neural Net
# 11            First Neural Net
# 12        Tuned Gradient Boost
# 13    Tuned Gradient Boost (2)
# 14  Downsampled Gradient Boost
#
#                                         description  precision    recall  \
# 0                                    First DT Model   0.888055  0.926638
# 1                                   Second DT Model   0.710857  0.894444
# 2                                    first tuned RF   0.708951  0.878917
# 3                                    out of the box   0.777580  0.745014
# 4                                    out of the box   0.751989  0.767521
# 5                                    out of the box   0.769559  0.745442
# 6                     max_depth=1, n_estimators=296   0.769559  0.745442
# 7                                      tuned C only   0.585827  0.052991
# 8                                    out of the box   0.692568  0.058405
# 9                                    out of the box   0.653266  1.000000
# 10       7 hidden layers, 30 nodes each, 100 epochs   0.526578  0.045157
# 11  7 hidden layers, various nodes each, 100 epochs   0.526578  0.045157
# 12        n_estimators = 300, default learning rate   0.745313  0.804131
# 13                  n_estimators = 300, max_depth=5   0.783238  0.447293
# 14                  n_estimators = 300, max_depth=5   0.719980  0.836182
#
#           F1
# 0   0.906936
# 1   0.792153
# 2   0.784837
# 3   0.760949
# 4   0.759676
# 5   0.757308
# 6   0.757308
# 7   0.097191
# 8   0.107725
# 9   0.790274
# 10  0.083180
# 11  0.083180
# 12  0.773606
# 13  0.569408
# 14  0.773743

# %%
model_comparison_df.to_csv('df.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 model_comparison_df.to_csv('df.csv')
#
# NameError: name 'model_comparison_df' is not defined

# %% [markdown]
# Let's look at the confusion matrix for this model:

# %%
plot_confusion_matrix(gbm, X_test_ss, y_test, cmap='Reds');

# %% [markdown]
# Our "best" model thus far is at index location $11$ in the table above. That is the model we will be using for our pipeline in our model application.

# %%
model_comparison_df.iloc[11]
# Out:
# Model Instance                                   First Neural Net
# description       7 hidden layers, various nodes each, 100 epochs
# precision                                                0.526578
# recall                                                   0.045157
# F1                                                        0.08318
# Name: 11, dtype: object

# %%
gbm_tuned2
# Out:
# GradientBoostingClassifier(min_samples_split=4, n_estimators=300)

# %% [markdown]
# With a pipeline, we can combine the steps of scaling our data and running the model:

# %%
from sklearn.pipeline import Pipeline

# %%
estimators = [('normalize', StandardScaler()),
             ('gradboost', GradientBoostingClassifier(min_samples_split=4, n_estimators=300))]

pipe = Pipeline(estimators)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('normalize', StandardScaler()),
#                 ('gradboost',
#                  GradientBoostingClassifier(min_samples_split=4,
#                                             n_estimators=300))])

# %%
pipe.score(X_test, y_test)
# Out:
# 0.6937465103294249

# %%
import joblib

# %% [markdown]
# The below line is to save the model to a `.pkl` file. It is commented out so the file does not save to anyone's machine.

# %%
#joblib.dump(pipe, "gradboost.pkl")

# %% [markdown]
# ## Conclusion
#
# In this notebook we have done the following:
# - Tried out various different model types including Decision trees, random forests, Neural Networks, and Gradient Boosting methods
# - We ultimately decided on a Gradient Boosting model and attempted to tune it's hyperparameters without much successs.
# - We exported our model to a `.pkl` file so it can be used for further applications.

# %% [markdown]
# ## Project Conclusion:
# - The end of this notebook concludes the Airbnb host score prediction project. Some next steps are listed below:
#
#     1. Trim down/automate the notebooks further
#     2. Deploy the model to a web app
#     3. Allow for prediction in more cities
#
# If you've made it this far, thank you for reading!
