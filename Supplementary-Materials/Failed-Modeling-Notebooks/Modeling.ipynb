# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
X_train = pd.read_csv('Modeling_Datasets/X_train.csv', index_col=[0])
X_val = pd.read_csv('Modeling_Datasets/X_val.csv', index_col=[0])
X_test = pd.read_csv('Modeling_Datasets/X_test.csv', index_col=[0])
y_train = pd.read_csv('Modeling_Datasets/y_train.csv', index_col=[0])
y_val = pd.read_csv('Modeling_Datasets/y_val.csv', index_col=[0])
y_test = pd.read_csv('Modeling_Datasets/y_test.csv', index_col=[0])

# %% [markdown]
# Now let's check the shape of each dataset to ensure that everything was read in correctly.

# %%
print(f'X_train shape: {X_train.shape}')
print(f'X_val shape: {X_val.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'y_val shape: {y_val.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (20366, 374)
# X_val shape: (5092, 374)
# X_test shape: (10911, 374)
# y_train shape: (20366, 1)
# y_val shape: (5092, 1)
# y_test shape: (10911, 1)

# %%
y_test
# Out:
#        review_scores_rating
# 2349                      0
# 19967                     1
# 23310                     1
# 25143                     1
# 26809                     1
# ...                     ...
# 25293                     1
# 4526                      1
# 34884                     0
# 8756                      1
# 11906                     1
#
# [10911 rows x 1 columns]

# %%
X_test
# Out:
#        host_is_superhost  host_total_listings_count  host_has_profile_pic  \
# 2349               False                        0.0                  True
# 19967              False                        2.0                  True
# 23310              False                        2.0                  True
# 25143              False                       50.0                  True
# 26809              False                        1.0                  True
# ...                  ...                        ...                   ...
# 25293              False                        1.0                  True
# 4526               False                        1.0                  True
# 34884              False                        1.0                  True
# 8756                True                        5.0                  True
# 11906              False                       55.0                  True
#
#        host_identity_verified  latitude  longitude  accommodates  \
# ...

# %% [markdown]
# Now we have all of our training, validation and testing sets read in, we can use the `CountVectorizer` to create a bag of words model for the two text columns in our `X` datasets.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
X_train_name = X_train['name']
X_val_name = X_val['name']
X_test_name = X_test['name']
X_train_desc = X_train['description']
X_val_desc = X_val['description']
X_test_desc = X_test['description']

# %%
def get_bagofwords(data)
